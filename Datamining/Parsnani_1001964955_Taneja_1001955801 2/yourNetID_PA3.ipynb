# %% [markdown]
# # PA 3: Association Analysis - Apriori Algorithm

# %% [markdown]
# ## Student Details
#
# Student Name: Jayesh Parsnani and ID:1001964955
# Student Name: Gaurav Taneja and ID:1001955801

# %% [markdown]
# ## Submission Instructions
#
#
# Step 1: Rename this file to 'yourNetID_PA3.ipnyb' and the report file to 'yourNetID_PA3.pdf' <br>
#
# Step 2: Upload all the document separately onto canvas  <br>**Not in a zip file. 20 points will be deducted if you don't follow the instruction**  <br>
# Note: Your submission should include ONLY the following files: <br>
#     * apriory.py  <br>
#     * yourNetID_PA3.ipynb  <br>
#     * yourNetID_PA3.pdf  <br>
#     * dataset.csv  <br>
#     * toyDS.csv <br>

# %% [markdown]
# ## Programming Assignment Details
#
# Before you start:
# - Note that this is an individual assignment.
# - Be familiar with the algorithm and with the dataset.
# - If you use external sources make sure that you cite them, and be specific!
# - Make sure that your code is running before you upload your submission file. TA will not debug your code.
# - Start early!
#
#
# For this assignment, you will have to use:
# * Jupyter notebook,
# * the 'Random Shopping cart' dataset [01],
# * and the Apriori Algorithm (apriory.py)[02]. Note that the apriory.py file is modified to run with Python 3.

# %% [markdown]
# ## ** Do Not Delete the Above Cell** <br>
# 10 points will be deducted if the instructions are not followed

# %% [markdown]
# ## - - - - - - - - - - - - - - - - - - - - - - - SOLUTION - - - - - - - - - - - - - - - - - - - - - - -

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return False;
# }

# %%
# Import your Libraries
import pandas as pd

# %% [markdown]
# ### Task 1: DataSet Preprocess
# Before you start you need to modify your dataset 'dataset_group.csv' to look like the toyDS.csv.  Each transaction is at one line with a variable length.  Discard the date attribute (1st attribute) from your dataset.  For example, in your dataset transaction#4 should look like:
#
#     cereals,juice,lunch meat,soda,toilet paper,all-purpose
#
# Export your modified dataset in a file named 'dataset.csv'.
#
# Use pandas to Read and Print the first 7 transactions of the 'dataset.csv'.

# %%
from IPython.display import Image
print ('ScreenShot of the toyDS.csv')
Image("SampleScreen01.png")
# Out:
# ScreenShot of the toyDS.csv

# %%
# # # # # # # # #  Code for Task 1 # # # # # # # # #
df = pd.read_csv('C:/Users/16824/OneDrive/Desktop/Project/Data Mining/Assignment3/assignment3-1/assignment3\dataset_group.csv', sep=',', header=None,names=['Date', 'Class','Items'])
tups = [('Items', ','.join), ('count', 'size')]
df1 = df['Items'].astype(str).groupby(df['Class']).agg(tups).reset_index()
df1.drop(['Class','count'],axis= 1,inplace= True)

# %%
# # #  Solution  # # #
data=df1['Items'].str.split(',',expand=True)
data.to_csv('C:/Users/16824/OneDrive/Desktop/Project/Data Mining/Assignment3/assignment3-1/assignment3\dataset.csv',sep=',',mode='w',index= False, header=None)
data.head(7)
# Out:
#                   0             1              2             3             4   \
# 0             yogurt          pork  sandwich bags    lunch meat  all- purpose
# 1       toilet paper       shampoo      hand soap       waffles    vegetables
# 2               soda          pork           soap     ice cream  toilet paper
# 3            cereals         juice     lunch meat          soda  toilet paper
# 4    sandwich loaves         pasta      tortillas         mixes     hand soap
# 5  laundry detergent  toilet paper           eggs  toilet paper    vegetables
# 6   individual meals  paper towels      tortillas    vegetables          milk
#
#              5                             6                             7   \
# 0         flour                          soda                        butter
# 1       cheeses                         mixes                          milk
# 2  dinner rolls                     hand soap               spaghetti sauce
# 3  all- purpose                          None                          None
# 4  toilet paper                    vegetables                    vegetables
# 5        bagels  dishwashing liquid/detergent                       cereals
# 6     ice cream                         juice  dishwashing liquid/detergent
#
#               8                  9   ...               24       25  \
# 0     vegetables               beef  ...             None     None
# 1  sandwich bags  laundry detergent  ...             None     None
# 2           milk            ketchup  ...  spaghetti sauce     pork
# 3           None               None  ...             None     None
# 4   paper towels         vegetables  ...     all- purpose     soda
# 5   paper towels  laundry detergent  ...  spaghetti sauce  ketchup
# 6           soap      sandwich bags  ...             None     None
#
#              26       27    28          29          30    31    32    33
# 0          None     None  None        None        None  None  None  None
# 1          None     None  None        None        None  None  None  None
# 2    vegetables  cheeses  eggs  vegetables  vegetables  None  None  None
# 3          None     None  None        None        None  None  None  None
# 4        yogurt     None  None        None        None  None  None  None
# 5  all- purpose     milk  None        None        None  None  None  None
# 6          None     None  None        None        None  None  None  None
#
# [7 rows x 34 columns]

# %% [markdown]
# ### Task 2: Run apriory.py and Evaluate Results
#
# In this task, you have to find how you will be able to execute and print apriory results by making use only the apriory.py. In other words "DO NOT USE ANY OTHER LIBRARY FOR TASK 2!!!".
#
# (*) For those that are not familiar with python and coding this could be a quite demanding task.
#
#
# You will have to execute apriori algorithm "3" times for different combinations of support and confidence.
# Print the results of apriory for 'dataset.csv' by making use ONLY the provided methods.
#
# Do not forget to add your reasoning (explain the result outcome) at the top of each case in a nice and readable way.
#
# You are allowed to use the python print method to print your results. DO NOT add your reasoning as comments.

# %%
print ('# # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #') 
print ('Case 2 (minimum support=0.04 and minimum confidence=0.6)') 
print ('Case 2 Reasoning: We are getting maximum confidence when the support value is very low.The confidence value for support minmum support of 0.04 is 100 percent for the rules (lunch meat, dinner rolls, soda, ice cream) ==> (vegetables,) , 1.000 and (cereals, dishwashing liquid/detergent, eggs, poultry) ==> (vegetables,) , 1.000.')
print ('Case 2 Output:') 
# !python apriori.py -f dataset.csv -s 0.04 -c 0.6
# Out:
# # # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #
# Case 2 (minimum support=0.04 and minimum confidence=0.6)
# Case 2 Reasoning: We are getting maximum confidence when the support value is very low.The confidence value for support minmum support of 0.04 is 100 percent for the rules (lunch meat, dinner rolls, soda, ice cream) ==> (vegetables,) , 1.000 and (cereals, dishwashing liquid/detergent, eggs, poultry) ==> (vegetables,) , 1.000.
# Case 2 Output:
#
# ------------ITEMS-----------------
# item: ('fruits', 'toilet paper', 'poultry', 'cheeses') , 0.040
# item: ('yogurt', 'flour', 'dinner rolls', 'all- purpose') , 0.040
# item: ('pork', 'mixes', 'ketchup', 'beef') , 0.040
# item: ('eggs', 'cereals', 'poultry', 'laundry detergent') , 0.040
# item: ('tortillas', 'yogurt', 'sandwich bags', 'cheeses') , 0.040
# item: ('vegetables', 'butter', 'pork', 'individual meals') , 0.040
# item: ('yogurt', 'aluminum foil', 'toilet paper', 'mixes') , 0.040
# item: ('aluminum foil', 'cheeses', 'juice', 'laundry detergent') , 0.040
# item: ('lunch meat', 'eggs', 'cereals', 'poultry') , 0.040
# item: ('shampoo', 'sugar', 'hand soap', 'poultry') , 0.040
# item: ('coffee/tea', 'yogurt', 'juice', 'cheeses') , 0.040
# item: ('coffee/tea', 'ice cream', 'soda', 'eggs') , 0.040
# item: ('paper towels', 'ice cream', 'bagels', 'eggs') , 0.040
# item: ('mixes', 'cereals', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('yogurt', 'fruits', 'cereals', 'milk') , 0.040
# item: ('soda', 'spaghetti sauce', 'milk', 'laundry detergent') , 0.040
# item: ('sandwich bags', 'soda', 'flour', 'cheeses') , 0.040
# item: ('sandwich bags', 'ketchup', 'soda', 'milk') , 0.040
# item: ('ice cream', 'waffles', 'poultry', 'cheeses') , 0.040
# item: ('shampoo', 'aluminum foil', 'paper towels', 'individual meals') , 0.040
# item: ('lunch meat', 'dishwashing liquid/detergent', 'dinner rolls', 'poultry') , 0.040
# item: ('laundry detergent', 'sandwich loaves', 'poultry', 'cheeses') , 0.040
# item: ('shampoo', 'lunch meat', 'ice cream', 'cheeses') , 0.040
# item: ('soda', 'eggs', 'cereals', 'beef') , 0.040
# item: ('lunch meat', 'juice', 'poultry', 'all- purpose') , 0.040
# item: ('lunch meat', 'shampoo', 'fruits', 'beef') , 0.040
# item: ('vegetables', 'pork', 'sandwich loaves', 'hand soap') , 0.040
# item: ('yogurt', 'toilet paper', 'ketchup', 'juice') , 0.040
# item: ('lunch meat', 'juice', 'spaghetti sauce', 'dinner rolls') , 0.040
# item: ('fruits', 'ice cream', 'milk', 'beef') , 0.040
# item: ('tortillas', 'cereals', 'milk', 'poultry') , 0.040
# item: ('yogurt', 'eggs', 'dinner rolls', 'beef') , 0.040
# item: ('shampoo', 'yogurt', 'spaghetti sauce', 'juice') , 0.040
# item: ('lunch meat', 'sugar', 'soda', 'poultry') , 0.040
# item: ('lunch meat', 'toilet paper', 'eggs', 'milk') , 0.040
# item: ('all- purpose', 'fruits', 'poultry', 'beef') , 0.040
# item: ('sandwich bags', 'bagels', 'individual meals', 'cheeses') , 0.040
# item: ('soda', 'spaghetti sauce', 'poultry', 'cheeses') , 0.040
# item: ('yogurt', 'soda', 'eggs', 'milk') , 0.040
# item: ('lunch meat', 'fruits', 'waffles', 'cheeses') , 0.040
# item: ('aluminum foil', 'bagels', 'dishwashing liquid/detergent', 'juice') , 0.040
# item: ('sandwich bags', 'eggs', 'milk', 'poultry') , 0.040
# item: ('aluminum foil', 'waffles', 'pasta', 'eggs') , 0.040
# item: ('mixes', 'dishwashing liquid/detergent', 'juice', 'poultry') , 0.040
# item: ('coffee/tea', 'pasta', 'dishwashing liquid/detergent', 'dinner rolls') , 0.040
# item: ('yogurt', 'paper towels', 'pasta', 'soda') , 0.040
# item: ('yogurt', 'paper towels', 'pasta', 'poultry') , 0.040
# item: ('mixes', 'sandwich bags', 'ketchup', 'spaghetti sauce') , 0.040
# item: ('paper towels', 'eggs', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('fruits', 'waffles', 'poultry', 'beef') , 0.040
# item: ('coffee/tea', 'shampoo', 'toilet paper', 'cereals') , 0.040
# item: ('yogurt', 'sandwich bags', 'cereals', 'milk') , 0.040
# item: ('waffles', 'toilet paper', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('pork', 'bagels', 'spaghetti sauce', 'juice') , 0.040
# item: ('beef', 'laundry detergent', 'cereals', 'cheeses') , 0.040
# item: ('lunch meat', 'all- purpose', 'ice cream', 'laundry detergent') , 0.040
# item: ('mixes', 'sandwich bags', 'cereals', 'cheeses') , 0.040
# item: ('paper towels', 'soda', 'eggs', 'poultry') , 0.040
# item: ('beef', 'fruits', 'cereals', 'cheeses') , 0.040
# item: ('fruits', 'aluminum foil', 'spaghetti sauce', 'poultry') , 0.040
# item: ('lunch meat', 'yogurt', 'cereals', 'beef') , 0.040
# item: ('lunch meat', 'soap', 'individual meals', 'beef') , 0.040
# item: ('ice cream', 'cereals', 'milk', 'laundry detergent') , 0.040
# item: ('waffles', 'soda', 'spaghetti sauce', 'juice') , 0.040
# item: ('lunch meat', 'soap', 'ketchup', 'all- purpose') , 0.040
# item: ('ice cream', 'sandwich bags', 'cereals', 'poultry') , 0.040
# item: ('lunch meat', 'ice cream', 'eggs', 'poultry') , 0.040
# item: ('mixes', 'pasta', 'cereals', 'dinner rolls') , 0.040
# item: ('tortillas', 'mixes', 'sandwich bags', 'poultry') , 0.040
# item: ('all- purpose', 'soap', 'ketchup', 'laundry detergent') , 0.040
# item: ('lunch meat', 'bagels', 'spaghetti sauce', 'cereals') , 0.040
# item: ('coffee/tea', 'pork', 'soap', 'waffles') , 0.040
# item: ('mixes', 'sandwich bags', 'dinner rolls', 'poultry') , 0.040
# item: ('sugar', 'toilet paper', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('soda', 'milk', 'flour', 'cheeses') , 0.040
# item: ('aluminum foil', 'spaghetti sauce', 'cereals', 'cheeses') , 0.040
# item: ('yogurt', 'toilet paper', 'bagels', 'juice') , 0.040
# item: ('lunch meat', 'aluminum foil', 'toilet paper', 'poultry') , 0.040
# item: ('lunch meat', 'ice cream', 'bagels', 'cereals') , 0.040
# item: ('paper towels', 'ice cream', 'mixes', 'eggs') , 0.040
# item: ('pork', 'bagels', 'eggs', 'milk') , 0.040
# item: ('shampoo', 'paper towels', 'pasta', 'poultry') , 0.040
# item: ('yogurt', 'soda', 'spaghetti sauce', 'dinner rolls') , 0.040
# item: ('cereals', 'dinner rolls', 'poultry', 'all- purpose') , 0.040
# item: ('yogurt', 'waffles', 'soda', 'dinner rolls') , 0.040
# item: ('aluminum foil', 'paper towels', 'eggs', 'dinner rolls') , 0.040
# item: ('tortillas', 'soap', 'ice cream', 'soda') , 0.040
# item: ('coffee/tea', 'waffles', 'ketchup', 'dinner rolls') , 0.040
# item: ('sugar', 'mixes', 'soda', 'dishwashing liquid/detergent') , 0.040
# item: ('ice cream', 'soda', 'spaghetti sauce', 'laundry detergent') , 0.040
# item: ('lunch meat', 'flour', 'dinner rolls', 'poultry') , 0.040
# item: ('ice cream', 'sandwich loaves', 'dinner rolls', 'poultry') , 0.040
# item: ('coffee/tea', 'waffles', 'sandwich bags', 'ketchup') , 0.040
# item: ('ice cream', 'butter', 'soda', 'eggs') , 0.040
# item: ('yogurt', 'soap', 'aluminum foil', 'individual meals') , 0.040
# item: ('coffee/tea', 'juice', 'poultry', 'all- purpose') , 0.040
# item: ('sandwich bags', 'cereals', 'poultry', 'beef') , 0.040
# item: ('shampoo', 'aluminum foil', 'toilet paper', 'cereals') , 0.040
# item: ('yogurt', 'waffles', 'cereals', 'poultry') , 0.040
# item: ('soap', 'sandwich bags', 'milk', 'poultry') , 0.040
# item: ('lunch meat', 'soap', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('ice cream', 'paper towels', 'ketchup', 'juice') , 0.040
# item: ('mixes', 'dinner rolls', 'poultry', 'all- purpose') , 0.040
# item: ('butter', 'spaghetti sauce', 'poultry', 'laundry detergent') , 0.040
# item: ('butter', 'sandwich bags', 'soda', 'cheeses') , 0.040
# item: ('shampoo', 'yogurt', 'pork', 'dinner rolls') , 0.040
# item: ('soap', 'waffles', 'sandwich bags', 'spaghetti sauce') , 0.040
# item: ('aluminum foil', 'ice cream', 'butter', 'cheeses') , 0.040
# item: ('tortillas', 'coffee/tea', 'pasta', 'poultry') , 0.040
# item: ('bagels', 'spaghetti sauce', 'milk', 'dinner rolls') , 0.040
# item: ('lunch meat', 'ice cream', 'waffles', 'poultry') , 0.040
# item: ('waffles', 'dishwashing liquid/detergent', 'flour', 'cheeses') , 0.040
# item: ('lunch meat', 'butter', 'paper towels', 'bagels') , 0.040
# item: ('fruits', 'soap', 'waffles', 'cheeses') , 0.040
# item: ('sandwich loaves', 'mixes', 'ketchup', 'cheeses') , 0.040
# item: ('juice', 'paper towels', 'eggs', 'dinner rolls') , 0.040
# item: ('vegetables', 'pork', 'pasta', 'juice') , 0.040
# item: ('yogurt', 'fruits', 'cereals', 'cheeses') , 0.040
# item: ('pasta', 'eggs', 'dinner rolls', 'cheeses') , 0.040
# item: ('yogurt', 'mixes', 'milk', 'cheeses') , 0.040
# item: ('pork', 'sandwich bags', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('sandwich bags', 'eggs', 'soda', 'milk') , 0.040
# item: ('yogurt', 'pasta', 'eggs', 'soda') , 0.040
# item: ('coffee/tea', 'lunch meat', 'sugar', 'poultry') , 0.040
# item: ('eggs', 'spaghetti sauce', 'poultry', 'cheeses') , 0.040
# item: ('lunch meat', 'waffles', 'spaghetti sauce', 'dishwashing liquid/detergent') , 0.040
# item: ('vegetables', 'hand soap', 'juice', 'cheeses') , 0.040
# item: ('vegetables', 'pork', 'sandwich loaves', 'pasta') , 0.040
# item: ('coffee/tea', 'shampoo', 'ice cream', 'cereals') , 0.040
# item: ('bagels', 'spaghetti sauce', 'cereals', 'cheeses') , 0.040
# item: ('aluminum foil', 'ice cream', 'mixes', 'ketchup') , 0.040
# item: ('tortillas', 'sandwich bags', 'bagels', 'dishwashing liquid/detergent') , 0.040
# item: ('lunch meat', 'aluminum foil', 'ice cream', 'individual meals') , 0.040
# item: ('coffee/tea', 'waffles', 'soda', 'ketchup') , 0.040
# item: ('pasta', 'cereals', 'dinner rolls', 'spaghetti sauce') , 0.040
# item: ('ice cream', 'waffles', 'eggs', 'poultry') , 0.040
# item: ('shampoo', 'soap', 'cereals', 'milk') , 0.040
# item: ('shampoo', 'ketchup', 'poultry', 'cheeses') , 0.040
# item: ('coffee/tea', 'eggs', 'ketchup', 'all- purpose') , 0.040
# item: ('yogurt', 'toilet paper', 'waffles', 'cereals') , 0.040
# item: ('all- purpose', 'paper towels', 'cereals', 'beef') , 0.040
# item: ('yogurt', 'sandwich loaves', 'toilet paper', 'juice') , 0.040
# item: ('paper towels', 'cereals', 'juice', 'spaghetti sauce') , 0.040
# item: ('soap', 'ketchup', 'flour', 'all- purpose') , 0.040
# item: ('yogurt', 'waffles', 'sandwich bags', 'cereals') , 0.040
# item: ('waffles', 'cereals', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('fruits', 'toilet paper', 'eggs', 'cheeses') , 0.040
# item: ('sugar', 'pasta', 'cereals', 'dinner rolls') , 0.040
# item: ('vegetables', 'pork', 'fruits', 'hand soap') , 0.040
# item: ('aluminum foil', 'spaghetti sauce', 'poultry', 'beef') , 0.040
# item: ('waffles', 'soda', 'eggs', 'laundry detergent') , 0.040
# item: ('paper towels', 'pasta', 'eggs', 'cheeses') , 0.040
# item: ('coffee/tea', 'waffles', 'cereals', 'juice') , 0.040
# item: ('juice', 'soap', 'waffles', 'dinner rolls') , 0.040
# item: ('soda', 'eggs', 'individual meals', 'milk') , 0.040
# item: ('yogurt', 'sandwich bags', 'eggs', 'cheeses') , 0.040
# item: ('coffee/tea', 'lunch meat', 'soda', 'dishwashing liquid/detergent') , 0.040
# item: ('aluminum foil', 'spaghetti sauce', 'poultry', 'cereals') , 0.040
# item: ('beef', 'sugar', 'poultry', 'cheeses') , 0.040
# item: ('bagels', 'dinner rolls', 'poultry', 'beef') , 0.040
# item: ('pasta', 'eggs', 'cereals', 'bagels') , 0.040
# item: ('waffles', 'bagels', 'eggs', 'dinner rolls') , 0.040
# item: ('lunch meat', 'fruits', 'waffles', 'sandwich bags') , 0.040
# item: ('aluminum foil', 'butter', 'mixes', 'poultry') , 0.040
# item: ('aluminum foil', 'paper towels', 'pasta', 'poultry') , 0.040
# item: ('yogurt', 'pasta', 'cereals', 'poultry') , 0.040
# item: ('yogurt', 'fruits', 'bagels', 'cereals') , 0.040
# item: ('lunch meat', 'soap', 'sandwich loaves', 'waffles') , 0.040
# item: ('fruits', 'vegetables', 'sugar', 'juice') , 0.040
# item: ('lunch meat', 'fruits', 'ice cream', 'spaghetti sauce') , 0.040
# item: ('dishwashing liquid/detergent', 'dinner rolls', 'poultry', 'beef') , 0.040
# item: ('waffles', 'soda', 'eggs', 'juice') , 0.040
# item: ('coffee/tea', 'ketchup', 'dinner rolls', 'poultry') , 0.040
# item: ('shampoo', 'vegetables', 'hand soap', 'all- purpose') , 0.040
# item: ('pasta', 'sugar', 'ice cream', 'soda') , 0.040
# item: ('vegetables', 'paper towels', 'butter', 'hand soap') , 0.040
# item: ('bagels', 'cereals', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('lunch meat', 'waffles', 'dishwashing liquid/detergent', 'all- purpose') , 0.040
# item: ('soap', 'soda', 'ketchup', 'spaghetti sauce') , 0.040
# item: ('lunch meat', 'bagels', 'cereals', 'juice') , 0.040
# item: ('yogurt', 'sugar', 'poultry', 'beef') , 0.040
# item: ('lunch meat', 'pasta', 'dishwashing liquid/detergent', 'dinner rolls') , 0.040
# item: ('butter', 'juice', 'poultry', 'laundry detergent') , 0.040
# item: ('toilet paper', 'waffles', 'dishwashing liquid/detergent', 'cheeses') , 0.040
# item: ('coffee/tea', 'sugar', 'dinner rolls', 'poultry') , 0.040
# item: ('yogurt', 'aluminum foil', 'sandwich loaves', 'mixes') , 0.040
# item: ('lunch meat', 'shampoo', 'aluminum foil', 'poultry') , 0.040
# item: ('fruits', 'ice cream', 'dishwashing liquid/detergent', 'cheeses') , 0.040
# item: ('yogurt', 'soap', 'cheeses', 'beef') , 0.040
# item: ('ketchup', 'spaghetti sauce', 'dinner rolls', 'poultry') , 0.040
# item: ('coffee/tea', 'yogurt', 'toilet paper', 'cereals') , 0.040
# item: ('aluminum foil', 'sandwich loaves', 'juice', 'poultry') , 0.040
# item: ('lunch meat', 'coffee/tea', 'individual meals', 'cereals') , 0.040
# item: ('aluminum foil', 'bagels', 'milk', 'beef') , 0.040
# item: ('lunch meat', 'yogurt', 'waffles', 'milk') , 0.040
# item: ('tortillas', 'eggs', 'dinner rolls', 'poultry') , 0.040
# item: ('lunch meat', 'ice cream', 'waffles', 'spaghetti sauce') , 0.040
# item: ('pasta', 'eggs', 'cereals', 'cheeses') , 0.040
# item: ('soap', 'sandwich bags', 'cereals', 'poultry') , 0.040
# item: ('sugar', 'soda', 'poultry', 'laundry detergent') , 0.040
# item: ('coffee/tea', 'lunch meat', 'yogurt', 'cereals') , 0.040
# item: ('lunch meat', 'individual meals', 'spaghetti sauce', 'poultry') , 0.040
# item: ('flour', 'dinner rolls', 'poultry', 'all- purpose') , 0.040
# item: ('pork', 'waffles', 'toilet paper', 'juice') , 0.040
# item: ('sugar', 'bagels', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('toilet paper', 'milk', 'poultry', 'cheeses') , 0.040
# item: ('pork', 'mixes', 'ketchup', 'poultry') , 0.040
# item: ('yogurt', 'pasta', 'poultry', 'all- purpose') , 0.040
# item: ('mixes', 'eggs', 'dinner rolls', 'poultry') , 0.040
# item: ('ice cream', 'pasta', 'spaghetti sauce', 'cereals') , 0.040
# item: ('fruits', 'aluminum foil', 'ice cream', 'dishwashing liquid/detergent') , 0.040
# item: ('lunch meat', 'soda', 'poultry', 'laundry detergent') , 0.040
# item: ('coffee/tea', 'yogurt', 'aluminum foil', 'ice cream') , 0.040
# item: ('aluminum foil', 'paper towels', 'cereals', 'spaghetti sauce') , 0.040
# item: ('aluminum foil', 'ice cream', 'pasta', 'spaghetti sauce') , 0.040
# item: ('fruits', 'pork', 'toilet paper', 'vegetables') , 0.040
# item: ('toilet paper', 'waffles', 'bagels', 'juice') , 0.040
# item: ('sandwich bags', 'eggs', 'milk', 'beef') , 0.040
# item: ('shampoo', 'bagels', 'spaghetti sauce', 'juice') , 0.040
# item: ('aluminum foil', 'toilet paper', 'ketchup', 'juice') , 0.040
# item: ('dinner rolls', 'milk', 'hand soap', 'poultry') , 0.040
# item: ('lunch meat', 'waffles', 'dishwashing liquid/detergent', 'dinner rolls') , 0.040
# item: ('yogurt', 'aluminum foil', 'fruits', 'cheeses') , 0.040
# item: ('shampoo', 'aluminum foil', 'paper towels', 'eggs') , 0.040
# item: ('paper towels', 'eggs', 'cereals', 'dishwashing liquid/detergent') , 0.040
# item: ('yogurt', 'eggs', 'spaghetti sauce', 'milk') , 0.040
# item: ('aluminum foil', 'ice cream', 'paper towels', 'beef') , 0.040
# item: ('coffee/tea', 'juice', 'ketchup', 'dinner rolls') , 0.040
# item: ('coffee/tea', 'paper towels', 'dishwashing liquid/detergent', 'milk') , 0.040
# item: ('tortillas', 'yogurt', 'sandwich bags', 'pasta') , 0.040
# item: ('shampoo', 'juice', 'dinner rolls', 'beef') , 0.040
# item: ('yogurt', 'toilet paper', 'waffles', 'cheeses') , 0.040
# item: ('yogurt', 'fruits', 'milk', 'beef') , 0.040
# item: ('shampoo', 'vegetables', 'spaghetti sauce', 'flour') , 0.040
# item: ('soap', 'waffles', 'mixes', 'dishwashing liquid/detergent') , 0.040
# item: ('pork', 'vegetables', 'sandwich loaves', 'cereals') , 0.040
# item: ('spaghetti sauce', 'milk', 'poultry', 'cereals') , 0.040
# item: ('mixes', 'pasta', 'cereals', 'poultry') , 0.040
# item: ('yogurt', 'waffles', 'pasta', 'cereals') , 0.040
# item: ('soap', 'sandwich loaves', 'juice', 'poultry') , 0.040
# item: ('shampoo', 'aluminum foil', 'pasta', 'soda') , 0.040
# item: ('pork', 'soap', 'poultry', 'all- purpose') , 0.040
# item: ('sandwich loaves', 'individual meals', 'juice', 'poultry') , 0.040
# item: ('lunch meat', 'eggs', 'cereals', 'beef') , 0.040
# item: ('paper towels', 'ice cream', 'juice', 'cheeses') , 0.040
# item: ('yogurt', 'sugar', 'poultry', 'cheeses') , 0.040
# item: ('ice cream', 'bagels', 'poultry', 'cheeses') , 0.040
# item: ('soap', 'waffles', 'soda', 'dinner rolls') , 0.040
# item: ('paper towels', 'ice cream', 'cereals', 'dishwashing liquid/detergent') , 0.040
# item: ('waffles', 'pasta', 'cereals', 'dinner rolls') , 0.040
# item: ('yogurt', 'sandwich bags', 'eggs', 'dishwashing liquid/detergent') , 0.040
# item: ('aluminum foil', 'ice cream', 'sugar', 'dinner rolls') , 0.040
# item: ('soap', 'sandwich bags', 'spaghetti sauce', 'poultry') , 0.040
# item: ('paper towels', 'toilet paper', 'bagels', 'juice') , 0.040
# item: ('soap', 'paper towels', 'soda', 'ketchup') , 0.040
# item: ('soap', 'aluminum foil', 'sandwich loaves', 'poultry') , 0.040
# item: ('paper towels', 'mixes', 'dishwashing liquid/detergent', 'milk') , 0.040
# item: ('fruits', 'soap', 'waffles', 'spaghetti sauce') , 0.040
# item: ('coffee/tea', 'sandwich loaves', 'waffles', 'ketchup') , 0.040
# item: ('waffles', 'soda', 'spaghetti sauce', 'cheeses') , 0.040
# item: ('aluminum foil', 'ice cream', 'individual meals', 'poultry') , 0.040
# item: ('pasta', 'ice cream', 'bagels', 'cheeses') , 0.040
# item: ('soap', 'ice cream', 'milk', 'poultry') , 0.040
# item: ('yogurt', 'dishwashing liquid/detergent', 'milk', 'juice') , 0.040
# item: ('vegetables', 'butter', 'dinner rolls', 'beef') , 0.040
# item: ('shampoo', 'yogurt', 'coffee/tea', 'mixes') , 0.040
# item: ('soda', 'eggs', 'dinner rolls', 'all- purpose') , 0.040
# item: ('yogurt', 'fruits', 'aluminum foil', 'cereals') , 0.040
# item: ('soda', 'spaghetti sauce', 'milk', 'poultry') , 0.040
# item: ('sugar', 'pasta', 'eggs', 'soda') , 0.040
# item: ('soap', 'aluminum foil', 'ice cream', 'beef') , 0.040
# item: ('soap', 'ice cream', 'waffles', 'individual meals') , 0.040
# item: ('paper towels', 'toilet paper', 'individual meals', 'all- purpose') , 0.040
# item: ('toilet paper', 'bagels', 'dishwashing liquid/detergent', 'dinner rolls') , 0.040
# item: ('ice cream', 'eggs', 'poultry', 'cheeses') , 0.040
# item: ('soap', 'paper towels', 'ketchup', 'milk') , 0.040
# item: ('coffee/tea', 'soap', 'toilet paper', 'ketchup') , 0.040
# item: ('coffee/tea', 'sugar', 'waffles', 'soda') , 0.040
# item: ('shampoo', 'lunch meat', 'paper towels', 'ice cream') , 0.040
# item: ('fruits', 'waffles', 'spaghetti sauce', 'beef') , 0.040
# item: ('coffee/tea', 'bagels', 'cereals', 'juice') , 0.040
# item: ('soda', 'eggs', 'dinner rolls', 'ketchup') , 0.040
# item: ('paper towels', 'toilet paper', 'ice cream', 'cereals') , 0.040
# item: ('paper towels', 'ketchup', 'dishwashing liquid/detergent', 'milk') , 0.040
# item: ('mixes', 'eggs', 'dishwashing liquid/detergent', 'milk') , 0.040
# item: ('lunch meat', 'soap', 'waffles', 'spaghetti sauce') , 0.040
# item: ('lunch meat', 'soda', 'dishwashing liquid/detergent', 'laundry detergent') , 0.040
# item: ('soap', 'dinner rolls', 'poultry', 'cheeses') , 0.040
# item: ('toilet paper', 'bagels', 'dinner rolls', 'poultry') , 0.040
# item: ('sandwich loaves', 'ketchup', 'flour', 'cheeses') , 0.040
# item: ('yogurt', 'pasta', 'eggs', 'milk') , 0.040
# item: ('pasta', 'bagels', 'soda', 'dinner rolls') , 0.040
# item: ('butter', 'mixes', 'dishwashing liquid/detergent', 'cheeses') , 0.040
# item: ('butter', 'sugar', 'eggs', 'poultry') , 0.040
# item: ('sugar', 'eggs', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('waffles', 'bagels', 'eggs', 'soda') , 0.040
# item: ('lunch meat', 'ice cream', 'spaghetti sauce', 'dinner rolls') , 0.040
# item: ('hand soap', 'dinner rolls', 'poultry', 'beef') , 0.040
# item: ('paper towels', 'cheeses', 'sandwich bags', 'beef') , 0.040
# item: ('pork', 'soap', 'waffles', 'juice') , 0.040
# item: ('yogurt', 'eggs', 'milk', 'beef') , 0.040
# item: ('shampoo', 'soap', 'dinner rolls', 'poultry') , 0.040
# item: ('soap', 'paper towels', 'aluminum foil', 'ketchup') , 0.040
# item: ('tortillas', 'yogurt', 'mixes', 'poultry') , 0.040
# item: ('lunch meat', 'paper towels', 'ice cream', 'dinner rolls') , 0.040
# item: ('yogurt', 'sandwich bags', 'eggs', 'dinner rolls') , 0.040
# item: ('lunch meat', 'waffles', 'dishwashing liquid/detergent', 'juice') , 0.040
# item: ('mixes', 'cereals', 'dinner rolls', 'cheeses') , 0.040
# item: ('yogurt', 'toilet paper', 'milk', 'beef') , 0.040
# item: ('toilet paper', 'waffles', 'soda', 'spaghetti sauce') , 0.040
# item: ('soap', 'waffles', 'mixes', 'spaghetti sauce') , 0.040
# item: ('coffee/tea', 'aluminum foil', 'flour', 'juice') , 0.040
# item: ('yogurt', 'bagels', 'dinner rolls', 'poultry') , 0.040
# item: ('pasta', 'eggs', 'bagels', 'dinner rolls') , 0.040
# item: ('soap', 'aluminum foil', 'pasta', 'soda') , 0.040
# item: ('sandwich bags', 'soda', 'ketchup', 'spaghetti sauce') , 0.040
# item: ('yogurt', 'waffles', 'cereals', 'cheeses') , 0.040
# item: ('yogurt', 'aluminum foil', 'spaghetti sauce', 'cheeses') , 0.040
# item: ('soap', 'ice cream', 'sandwich bags', 'poultry') , 0.040
# item: ('shampoo', 'coffee/tea', 'paper towels', 'eggs') , 0.040
# item: ('mixes', 'sandwich bags', 'soda', 'milk') , 0.040
# item: ('shampoo', 'aluminum foil', 'eggs', 'juice') , 0.040
# item: ('dinner rolls', 'mixes', 'dishwashing liquid/detergent', 'hand soap') , 0.040
# item: ('butter', 'dishwashing liquid/detergent', 'poultry', 'cheeses') , 0.040
# item: ('lunch meat', 'yogurt', 'coffee/tea', 'aluminum foil') , 0.040
# item: ('paper towels', 'ice cream', 'spaghetti sauce', 'juice') , 0.040
# item: ('lunch meat', 'yogurt', 'juice', 'poultry') , 0.040
# item: ('ice cream', 'waffles', 'sandwich bags', 'cheeses') , 0.040
# item: ('yogurt', 'waffles', 'bagels', 'individual meals') , 0.040
# item: ('coffee/tea', 'soap', 'sandwich bags', 'ketchup') , 0.040
# item: ('fruits', 'spaghetti sauce', 'dishwashing liquid/detergent', 'beef') , 0.040
# item: ('aluminum foil', 'waffles', 'spaghetti sauce', 'dinner rolls') , 0.040
# item: ('ice cream', 'butter', 'sandwich bags', 'cheeses') , 0.040
# item: ('paper towels', 'pasta', 'eggs', 'all- purpose') , 0.040
# item: ('aluminum foil', 'soap', 'waffles', 'sandwich loaves') , 0.040
# item: ('pasta', 'cereals', 'poultry', 'cheeses') , 0.040
# item: ('tortillas', 'fruits', 'vegetables', 'hand soap') , 0.040
# item: ('aluminum foil', 'soap', 'waffles', 'cheeses') , 0.040
# item: ('yogurt', 'aluminum foil', 'pasta', 'dinner rolls') , 0.040
# item: ('yogurt', 'dishwashing liquid/detergent', 'dinner rolls', 'poultry') , 0.040
# item: ('soap', 'waffles', 'toilet paper', 'individual meals') , 0.040
# item: ('mixes', 'individual meals', 'poultry', 'laundry detergent') , 0.040
# item: ('eggs', 'waffles', 'soda', 'ketchup') , 0.040
# item: ('yogurt', 'toilet paper', 'individual meals', 'juice') , 0.040
# item: ('aluminum foil', 'dinner rolls', 'poultry', 'beef') , 0.040
# item: ('shampoo', 'pasta', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('shampoo', 'toilet paper', 'soda', 'juice') , 0.040
# item: ('ice cream', 'sugar', 'waffles', 'poultry') , 0.040
# item: ('waffles', 'soda', 'spaghetti sauce', 'all- purpose') , 0.040
# item: ('tortillas', 'toilet paper', 'bagels', 'dinner rolls') , 0.040
# item: ('tortillas', 'coffee/tea', 'yogurt', 'milk') , 0.040
# item: ('yogurt', 'dinner rolls', 'poultry', 'cheeses') , 0.040
# item: ('waffles', 'soda', 'cereals', 'laundry detergent') , 0.040
# item: ('lunch meat', 'paper towels', 'milk', 'all- purpose') , 0.040
# item: ('pasta', 'soda', 'milk', 'beef') , 0.040
# item: ('paper towels', 'ice cream', 'juice', 'poultry') , 0.040
# item: ('soda', 'eggs', 'ketchup', 'beef') , 0.040
# item: ('sugar', 'milk', 'poultry', 'laundry detergent') , 0.040
# item: ('sugar', 'pasta', 'cereals', 'cheeses') , 0.040
# item: ('dishwashing liquid/detergent', 'pasta', 'soda', 'flour') , 0.040
# item: ('coffee/tea', 'pasta', 'bagels', 'cereals') , 0.040
# item: ('yogurt', 'soda', 'spaghetti sauce', 'juice') , 0.040
# item: ('shampoo', 'lunch meat', 'flour', 'juice') , 0.040
# item: ('yogurt', 'sugar', 'cereals', 'poultry') , 0.040
# item: ('toilet paper', 'bagels', 'cereals', 'dishwashing liquid/detergent') , 0.040
# item: ('tortillas', 'bagels', 'individual meals', 'cereals') , 0.040
# item: ('yogurt', 'eggs', 'cereals', 'cheeses') , 0.040
# item: ('butter', 'sugar', 'soda', 'eggs') , 0.040
# item: ('coffee/tea', 'aluminum foil', 'mixes', 'poultry') , 0.040
# item: ('toilet paper', 'bagels', 'eggs', 'milk') , 0.040
# item: ('mixes', 'bagels', 'poultry', 'cheeses') , 0.040
# item: ('tortillas', 'shampoo', 'vegetables', 'spaghetti sauce') , 0.040
# item: ('lunch meat', 'coffee/tea', 'sandwich loaves', 'waffles') , 0.040
# item: ('shampoo', 'coffee/tea', 'poultry', 'cheeses') , 0.040
# item: ('pasta', 'eggs', 'soda', 'laundry detergent') , 0.040
# item: ('aluminum foil', 'mixes', 'sandwich bags', 'cheeses') , 0.040
# item: ('fruits', 'ice cream', 'paper towels', 'beef') , 0.040
# item: ('soap', 'butter', 'aluminum foil', 'ketchup') , 0.040
# item: ('mixes', 'spaghetti sauce', 'poultry', 'laundry detergent') , 0.040
# item: ('spaghetti sauce', 'dishwashing liquid/detergent', 'poultry', 'laundry detergent') , 0.040
# item: ('lunch meat', 'ice cream', 'waffles', 'laundry detergent') , 0.040
# item: ('waffles', 'sugar', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('yogurt', 'all- purpose', 'ketchup', 'laundry detergent') , 0.040
# item: ('lunch meat', 'ice cream', 'waffles', 'pasta') , 0.040
# item: ('pasta', 'individual meals', 'dinner rolls', 'poultry') , 0.040
# item: ('fruits', 'ice cream', 'pasta', 'eggs') , 0.040
# item: ('soda', 'eggs', 'juice', 'poultry') , 0.040
# item: ('yogurt', 'milk', 'juice', 'beef') , 0.040
# item: ('lunch meat', 'waffles', 'bagels', 'dishwashing liquid/detergent') , 0.040
# item: ('coffee/tea', 'lunch meat', 'aluminum foil', 'juice') , 0.040
# item: ('yogurt', 'paper towels', 'ice cream', 'cheeses') , 0.040
# item: ('tortillas', 'yogurt', 'dinner rolls', 'poultry') , 0.040
# item: ('paper towels', 'eggs', 'spaghetti sauce', 'dinner rolls') , 0.040
# item: ('toilet paper', 'soda', 'spaghetti sauce', 'milk') , 0.040
# item: ('coffee/tea', 'soap', 'paper towels', 'ketchup') , 0.040
# item: ('pork', 'bagels', 'eggs', 'dishwashing liquid/detergent') , 0.040
# item: ('paper towels', 'ice cream', 'eggs', 'spaghetti sauce') , 0.040
# item: ('yogurt', 'sandwich bags', 'juice', 'poultry') , 0.040
# item: ('beef', 'ice cream', 'cereals', 'cheeses') , 0.040
# item: ('fruits', 'aluminum foil', 'ice cream', 'bagels') , 0.040
# item: ('shampoo', 'yogurt', 'aluminum foil', 'cheeses') , 0.040
# item: ('lunch meat', 'bagels', 'dishwashing liquid/detergent', 'juice') , 0.040
# item: ('pasta', 'eggs', 'individual meals', 'dinner rolls') , 0.040
# item: ('yogurt', 'bagels', 'individual meals', 'poultry') , 0.040
# item: ('bagels', 'eggs', 'individual meals', 'dishwashing liquid/detergent') , 0.040
# item: ('yogurt', 'bagels', 'milk', 'poultry') , 0.040
# item: ('shampoo', 'lunch meat', 'juice', 'dinner rolls') , 0.040
# item: ('pasta', 'eggs', 'spaghetti sauce', 'poultry') , 0.040
# item: ('tortillas', 'mixes', 'cereals', 'poultry') , 0.040
# item: ('aluminum foil', 'waffles', 'mixes', 'ketchup') , 0.040
# item: ('soap', 'mixes', 'soda', 'dishwashing liquid/detergent') , 0.040
# item: ('lunch meat', 'butter', 'waffles', 'toilet paper') , 0.040
# item: ('lunch meat', 'individual meals', 'spaghetti sauce', 'cereals') , 0.040
# item: ('soap', 'soda', 'individual meals', 'poultry') , 0.040
# item: ('lunch meat', 'pork', 'vegetables', 'pasta') , 0.040
# item: ('lunch meat', 'soda', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('lunch meat', 'individual meals', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('aluminum foil', 'toilet paper', 'cereals', 'juice') , 0.040
# item: ('lunch meat', 'soda', 'dishwashing liquid/detergent', 'milk') , 0.040
# item: ('lunch meat', 'soap', 'waffles', 'eggs') , 0.040
# item: ('soap', 'paper towels', 'ketchup', 'poultry') , 0.040
# item: ('paper towels', 'eggs', 'dinner rolls', 'cheeses') , 0.040
# item: ('soap', 'spaghetti sauce', 'juice', 'all- purpose') , 0.040
# item: ('soda', 'juice', 'poultry', 'laundry detergent') , 0.040
# item: ('laundry detergent', 'aluminum foil', 'ice cream', 'cheeses') , 0.040
# item: ('vegetables', 'butter', 'pasta', 'milk') , 0.040
# item: ('yogurt', 'fruits', 'sandwich loaves', 'poultry') , 0.040
# item: ('yogurt', 'aluminum foil', 'spaghetti sauce', 'cereals') , 0.040
# item: ('yogurt', 'milk', 'juice', 'laundry detergent') , 0.040
# item: ('fruits', 'individual meals', 'bagels', 'spaghetti sauce') , 0.040
# item: ('shampoo', 'yogurt', 'lunch meat', 'dinner rolls') , 0.040
# item: ('aluminum foil', 'mixes', 'eggs', 'ketchup') , 0.040
# item: ('aluminum foil', 'ice cream', 'soda', 'eggs') , 0.040
# item: ('fruits', 'vegetables', 'toilet paper', 'pasta') , 0.040
# item: ('soap', 'paper towels', 'soda', 'eggs') , 0.040
# item: ('soap', 'waffles', 'pasta', 'cheeses') , 0.040
# item: ('yogurt', 'eggs', 'milk', 'all- purpose') , 0.040
# item: ('lunch meat', 'soap', 'ice cream', 'cheeses') , 0.040
# item: ('tortillas', 'vegetables', 'butter', 'beef') , 0.040
# item: ('waffles', 'soda', 'spaghetti sauce', 'dinner rolls') , 0.040
# item: ('lunch meat', 'fruits', 'paper towels', 'dishwashing liquid/detergent') , 0.040
# item: ('shampoo', 'mixes', 'cereals', 'cheeses') , 0.040
# item: ('yogurt', 'aluminum foil', 'ice cream', 'beef') , 0.040
# item: ('shampoo', 'aluminum foil', 'bagels', 'juice') , 0.040
# item: ('pasta', 'eggs', 'cereals', 'spaghetti sauce') , 0.040
# item: ('ice cream', 'waffles', 'toilet paper', 'cheeses') , 0.040
# item: ('shampoo', 'aluminum foil', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('beef', 'fruits', 'ice cream', 'cheeses') , 0.040
# item: ('soap', 'waffles', 'soda', 'milk') , 0.040
# item: ('lunch meat', 'soap', 'soda', 'flour') , 0.040
# item: ('lunch meat', 'waffles', 'sandwich loaves', 'dishwashing liquid/detergent') , 0.040
# item: ('shampoo', 'lunch meat', 'waffles', 'poultry') , 0.040
# item: ('ice cream', 'waffles', 'soda', 'spaghetti sauce') , 0.040
# item: ('lunch meat', 'paper towels', 'poultry', 'all- purpose') , 0.040
# item: ('ice cream', 'toilet paper', 'milk', 'juice') , 0.040
# item: ('coffee/tea', 'ice cream', 'milk', 'cheeses') , 0.040
# item: ('yogurt', 'ketchup', 'poultry', 'all- purpose') , 0.040
# item: ('aluminum foil', 'ice cream', 'mixes', 'cereals') , 0.040
# item: ('lunch meat', 'yogurt', 'aluminum foil', 'ice cream') , 0.040
# item: ('sandwich bags', 'dishwashing liquid/detergent', 'poultry', 'laundry detergent') , 0.040
# item: ('lunch meat', 'toilet paper', 'waffles', 'eggs') , 0.040
# item: ('pork', 'dishwashing liquid/detergent', 'dinner rolls', 'poultry') , 0.040
# item: ('beef', 'ketchup', 'juice', 'cheeses') , 0.040
# item: ('soda', 'eggs', 'milk', 'cheeses') , 0.040
# item: ('shampoo', 'yogurt', 'juice', 'laundry detergent') , 0.040
# item: ('lunch meat', 'aluminum foil', 'spaghetti sauce', 'poultry') , 0.040
# item: ('aluminum foil', 'paper towels', 'mixes', 'poultry') , 0.040
# item: ('tortillas', 'coffee/tea', 'ice cream', 'cheeses') , 0.040
# item: ('yogurt', 'sandwich bags', 'dinner rolls', 'cheeses') , 0.040
# item: ('lunch meat', 'individual meals', 'cereals', 'dishwashing liquid/detergent') , 0.040
# item: ('fruits', 'ice cream', 'pasta', 'dishwashing liquid/detergent') , 0.040
# item: ('shampoo', 'cereals', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('ice cream', 'bagels', 'cereals', 'cheeses') , 0.040
# item: ('lunch meat', 'mixes', 'poultry', 'beef') , 0.040
# item: ('coffee/tea', 'yogurt', 'sandwich bags', 'cheeses') , 0.040
# item: ('fruits', 'ice cream', 'paper towels', 'pasta') , 0.040
# item: ('soap', 'sandwich bags', 'soda', 'spaghetti sauce') , 0.040
# item: ('vegetables', 'butter', 'paper towels', 'beef') , 0.040
# item: ('soap', 'fruits', 'waffles', 'pasta') , 0.040

# %%
print ('# # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #') 
print ('Case 1 (minimum support=0.15 and minimum confidence=0.6)')
print ('Case 1 Reasoning: We get decerease in confidance when support count is increased. For the following rules (eggs, dinner rolls) ==> (vegetables) , Confidence: 0.899 and (yogurt, eggs) ==> (vegetables,) , 0.899. Thus, if people purchase eggs and dinner roll together then there is 89.9% chance that they will also going to purchase "vegetables" along with those items.')
print ('Case 1 Output:')
# !python apriori.py -f dataset.csv -s 0.15 -c 0.6
# Out:
# item: ('lunch meat', 'yogurt', 'shampoo', 'cereals') , 0.040
# item: ('aluminum foil', 'bagels', 'cereals', 'beef') , 0.040
# item: ('dishwashing liquid/detergent', 'pasta', 'eggs', 'bagels') , 0.040
# item: ('yogurt', 'waffles', 'juice', 'poultry') , 0.040
# item: ('lunch meat', 'yogurt', 'aluminum foil', 'cheeses') , 0.040
# item: ('pasta', 'eggs', 'poultry', 'all- purpose') , 0.040
# item: ('sugar', 'soda', 'poultry', 'beef') , 0.040
# item: ('paper towels', 'cereals', 'juice', 'beef') , 0.040
# item: ('coffee/tea', 'shampoo', 'ketchup', 'dinner rolls') , 0.040
# item: ('soda', 'eggs', 'juice', 'all- purpose') , 0.040
# item: ('coffee/tea', 'aluminum foil', 'dinner rolls', 'poultry') , 0.040
# item: ('toilet paper', 'pasta', 'eggs', 'bagels') , 0.040
# item: ('soda', 'eggs', 'dishwashing liquid/detergent', 'dinner rolls') , 0.040
# item: ('shampoo', 'coffee/tea', 'paper towels', 'juice') , 0.040
# item: ('coffee/tea', 'ice cream', 'sugar', 'cheeses') , 0.040
# item: ('lunch meat', 'butter', 'poultry', 'all- purpose') , 0.040
# item: ('ice cream', 'paper towels', 'pasta', 'beef') , 0.040
# item: ('yogurt', 'flour', 'juice', 'poultry') , 0.040
# item: ('soap', 'soda', 'ketchup', 'flour') , 0.040
# item: ('paper towels', 'mixes', 'dinner rolls', 'poultry') , 0.040
# item: ('waffles', 'pasta', 'bagels', 'dinner rolls') , 0.040
# item: ('lunch meat', 'soap', 'waffles', 'juice') , 0.040
# item: ('coffee/tea', 'soap', 'soda', 'cheeses') , 0.040
# item: ('paper towels', 'sandwich loaves', 'ice cream', 'individual meals') , 0.040
# item: ('lunch meat', 'shampoo', 'juice', 'laundry detergent') , 0.040
# item: ('shampoo', 'paper towels', 'cereals', 'poultry') , 0.040
# item: ('beef', 'vegetables', 'mixes', 'all- purpose') , 0.040
# item: ('waffles', 'soda', 'dishwashing liquid/detergent', 'laundry detergent') , 0.040
# item: ('ice cream', 'soda', 'spaghetti sauce', 'dinner rolls') , 0.040
# item: ('toilet paper', 'cereals', 'milk', 'laundry detergent') , 0.040
# item: ('aluminum foil', 'pasta', 'dishwashing liquid/detergent', 'dinner rolls') , 0.040
# item: ('ice cream', 'sandwich loaves', 'spaghetti sauce', 'cheeses') , 0.040
# item: ('fruits', 'pasta', 'spaghetti sauce', 'beef') , 0.040
# item: ('aluminum foil', 'ice cream', 'waffles', 'beef') , 0.040
# item: ('lunch meat', 'ice cream', 'individual meals', 'cereals') , 0.040
# item: ('vegetables', 'fruits', 'flour', 'juice') , 0.040
# item: ('cereals', 'dishwashing liquid/detergent', 'milk', 'beef') , 0.040
# item: ('ice cream', 'sandwich bags', 'bagels', 'cheeses') , 0.040
# item: ('fruits', 'ice cream', 'bagels', 'cereals') , 0.040
# item: ('paper towels', 'cereals', 'dishwashing liquid/detergent', 'all- purpose') , 0.040
# item: ('paper towels', 'dishwashing liquid/detergent', 'milk', 'poultry') , 0.040
# item: ('yogurt', 'pork', 'eggs', 'juice') , 0.040
# item: ('yogurt', 'aluminum foil', 'sandwich bags', 'juice') , 0.040
# item: ('paper towels', 'cereals', 'poultry', 'beef') , 0.040
# item: ('yogurt', 'mixes', 'milk', 'all- purpose') , 0.040
# item: ('yogurt', 'fruits', 'bagels', 'individual meals') , 0.040
# item: ('sandwich loaves', 'toilet paper', 'ketchup', 'cheeses') , 0.040
# item: ('vegetables', 'toilet paper', 'flour', 'beef') , 0.040
# item: ('lunch meat', 'fruits', 'spaghetti sauce', 'cheeses') , 0.040
# item: ('coffee/tea', 'yogurt', 'ice cream', 'cereals') , 0.040
# item: ('ice cream', 'sugar', 'waffles', 'beef') , 0.040
# item: ('lunch meat', 'soda', 'dishwashing liquid/detergent', 'dinner rolls') , 0.040
# item: ('aluminum foil', 'ice cream', 'sandwich loaves', 'individual meals') , 0.040
# item: ('tortillas', 'vegetables', 'fruits', 'sandwich bags') , 0.040
# item: ('soap', 'ice cream', 'fruits', 'pasta') , 0.040
# item: ('mixes', 'dishwashing liquid/detergent', 'poultry', 'all- purpose') , 0.040
# item: ('lunch meat', 'paper towels', 'eggs', 'milk') , 0.040
# item: ('lunch meat', 'fruits', 'paper towels', 'cheeses') , 0.040
# item: ('soap', 'ice cream', 'aluminum foil', 'paper towels') , 0.040
# item: ('tortillas', 'yogurt', 'sandwich bags', 'laundry detergent') , 0.040
# item: ('lunch meat', 'yogurt', 'waffles', 'poultry') , 0.040
# item: ('ice cream', 'paper towels', 'spaghetti sauce', 'cereals') , 0.040
# item: ('soap', 'cereals', 'dinner rolls', 'poultry') , 0.040
# item: ('soap', 'soda', 'spaghetti sauce', 'laundry detergent') , 0.040
# item: ('paper towels', 'soda', 'ketchup', 'milk') , 0.040
# item: ('eggs', 'waffles', 'ketchup', 'beef') , 0.040
# item: ('ice cream', 'waffles', 'bagels', 'dishwashing liquid/detergent') , 0.040
# item: ('sugar', 'individual meals', 'poultry', 'cheeses') , 0.040
# item: ('ice cream', 'sugar', 'waffles', 'cheeses') , 0.040
# item: ('ice cream', 'eggs', 'cereals', 'poultry') , 0.040
# item: ('soda', 'spaghetti sauce', 'flour', 'cheeses') , 0.040
# item: ('yogurt', 'toilet paper', 'soda', 'dinner rolls') , 0.040
# item: ('lunch meat', 'yogurt', 'flour', 'all- purpose') , 0.040
# item: ('yogurt', 'laundry detergent', 'milk', 'all- purpose') , 0.040
# item: ('aluminum foil', 'sandwich loaves', 'bagels', 'juice') , 0.040
# item: ('paper towels', 'mixes', 'eggs', 'dishwashing liquid/detergent') , 0.040
# item: ('shampoo', 'ice cream', 'poultry', 'beef') , 0.040
# item: ('shampoo', 'mixes', 'pasta', 'cereals') , 0.040
# item: ('ice cream', 'pasta', 'eggs', 'spaghetti sauce') , 0.040
# item: ('coffee/tea', 'shampoo', 'waffles', 'cereals') , 0.040
# item: ('soap', 'pasta', 'eggs', 'soda') , 0.040
# item: ('soap', 'ice cream', 'eggs', 'poultry') , 0.040
# item: ('ketchup', 'spaghetti sauce', 'juice', 'laundry detergent') , 0.040
# item: ('shampoo', 'cereals', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('ice cream', 'waffles', 'soda', 'flour') , 0.040
# item: ('coffee/tea', 'lunch meat', 'ice cream', 'individual meals') , 0.040
# item: ('lunch meat', 'fruits', 'dinner rolls', 'poultry') , 0.040
# item: ('yogurt', 'paper towels', 'eggs', 'dinner rolls') , 0.040
# item: ('aluminum foil', 'ice cream', 'ketchup', 'cheeses') , 0.040
# item: ('ice cream', 'sandwich loaves', 'sandwich bags', 'poultry') , 0.040
# item: ('lunch meat', 'pork', 'waffles', 'juice') , 0.040
# item: ('lunch meat', 'toilet paper', 'bagels', 'milk') , 0.040
# item: ('tortillas', 'lunch meat', 'toilet paper', 'bagels') , 0.040
# item: ('yogurt', 'bagels', 'spaghetti sauce', 'cheeses') , 0.040
# item: ('ice cream', 'spaghetti sauce', 'poultry', 'beef') , 0.040
# item: ('toilet paper', 'cereals', 'milk', 'poultry') , 0.040
# item: ('paper towels', 'toilet paper', 'juice', 'laundry detergent') , 0.040
# item: ('soda', 'dishwashing liquid/detergent', 'poultry', 'laundry detergent') , 0.040
# item: ('yogurt', 'aluminum foil', 'sandwich loaves', 'pasta') , 0.040
# item: ('waffles', 'pasta', 'eggs', 'dishwashing liquid/detergent') , 0.040
# item: ('ice cream', 'pasta', 'eggs', 'cereals') , 0.040
# item: ('eggs', 'ketchup', 'juice', 'all- purpose') , 0.040
# item: ('toilet paper', 'soda', 'ketchup', 'milk') , 0.040
# item: ('yogurt', 'pasta', 'milk', 'cheeses') , 0.040
# item: ('aluminum foil', 'paper towels', 'waffles', 'pasta') , 0.040
# item: ('dinner rolls', 'mixes', 'eggs', 'hand soap') , 0.040
# item: ('beef', 'pasta', 'sandwich bags', 'cheeses') , 0.040
# item: ('paper towels', 'ice cream', 'toilet paper', 'pasta') , 0.040
# item: ('sandwich bags', 'soda', 'milk', 'cheeses') , 0.040
# item: ('soap', 'soda', 'ketchup', 'cheeses') , 0.040
# item: ('sandwich bags', 'eggs', 'cereals', 'cheeses') , 0.040
# item: ('fruits', 'vegetables', 'hand soap', 'juice') , 0.040
# item: ('coffee/tea', 'fruits', 'vegetables', 'all- purpose') , 0.040
# item: ('yogurt', 'aluminum foil', 'ice cream', 'dinner rolls') , 0.040
# item: ('sugar', 'flour', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('shampoo', 'soap', 'juice', 'poultry') , 0.040
# item: ('soap', 'paper towels', 'sandwich bags', 'spaghetti sauce') , 0.040
# item: ('pasta', 'soda', 'poultry', 'laundry detergent') , 0.040
# item: ('soap', 'ice cream', 'soda', 'cheeses') , 0.040
# item: ('lunch meat', 'milk', 'poultry', 'all- purpose') , 0.040
# item: ('shampoo', 'aluminum foil', 'cheeses', 'laundry detergent') , 0.040
# item: ('fruits', 'paper towels', 'milk', 'beef') , 0.040
# item: ('pork', 'mixes', 'ketchup', 'milk') , 0.040
# item: ('soap', 'ice cream', 'soda', 'dishwashing liquid/detergent') , 0.040
# item: ('yogurt', 'fruits', 'sandwich bags', 'cereals') , 0.040
# item: ('fruits', 'aluminum foil', 'spaghetti sauce', 'beef') , 0.040
# item: ('tortillas', 'lunch meat', 'pork', 'bagels') , 0.040
# item: ('waffles', 'soda', 'eggs', 'milk') , 0.040
# item: ('ice cream', 'waffles', 'spaghetti sauce', 'juice') , 0.040
# item: ('coffee/tea', 'flour', 'juice', 'poultry') , 0.040
# item: ('shampoo', 'yogurt', 'coffee/tea', 'poultry') , 0.040
# item: ('fruits', 'soap', 'spaghetti sauce', 'beef') , 0.040
# item: ('shampoo', 'coffee/tea', 'lunch meat', 'juice') , 0.040
# item: ('coffee/tea', 'tortillas', 'ice cream', 'waffles') , 0.040
# item: ('spaghetti sauce', 'milk', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('lunch meat', 'coffee/tea', 'aluminum foil', 'waffles') , 0.040
# item: ('soap', 'aluminum foil', 'toilet paper', 'ketchup') , 0.040
# item: ('lunch meat', 'laundry detergent', 'ice cream', 'cheeses') , 0.040
# item: ('aluminum foil', 'individual meals', 'juice', 'poultry') , 0.040
# item: ('soap', 'sugar', 'eggs', 'poultry') , 0.040
# item: ('shampoo', 'ice cream', 'juice', 'poultry') , 0.040
# item: ('lunch meat', 'paper towels', 'ice cream', 'milk') , 0.040
# item: ('beef', 'laundry detergent', 'sandwich bags', 'cheeses') , 0.040
# item: ('yogurt', 'mixes', 'individual meals', 'poultry') , 0.040
# item: ('laundry detergent', 'waffles', 'dinner rolls', 'all- purpose') , 0.040
# item: ('tortillas', 'flour', 'mixes', 'dinner rolls') , 0.040
# item: ('paper towels', 'waffles', 'pasta', 'eggs') , 0.040
# item: ('fruits', 'ice cream', 'dishwashing liquid/detergent', 'beef') , 0.040
# item: ('aluminum foil', 'spaghetti sauce', 'juice', 'all- purpose') , 0.040
# item: ('yogurt', 'waffles', 'pasta', 'eggs') , 0.040
# item: ('ice cream', 'bagels', 'ketchup', 'cheeses') , 0.040
# item: ('shampoo', 'lunch meat', 'waffles', 'spaghetti sauce') , 0.040
# item: ('lunch meat', 'waffles', 'flour', 'cheeses') , 0.040
# item: ('soap', 'soda', 'eggs', 'individual meals') , 0.040
# item: ('lunch meat', 'coffee/tea', 'paper towels', 'cereals') , 0.040
# item: ('ice cream', 'cereals', 'milk', 'cheeses') , 0.040
# item: ('aluminum foil', 'ice cream', 'pasta', 'eggs') , 0.040
# item: ('yogurt', 'sandwich bags', 'soda', 'cheeses') , 0.040
# item: ('coffee/tea', 'sugar', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('sugar', 'mixes', 'spaghetti sauce', 'poultry') , 0.040
# item: ('cereals', 'dinner rolls', 'poultry', 'cheeses') , 0.040
# item: ('waffles', 'ketchup', 'juice', 'cheeses') , 0.040
# item: ('shampoo', 'pork', 'vegetables', 'pasta') , 0.040
# item: ('ice cream', 'eggs', 'milk', 'beef') , 0.040
# item: ('milk', 'juice', 'poultry', 'laundry detergent') , 0.040
# item: ('aluminum foil', 'toilet paper', 'juice', 'laundry detergent') , 0.040
# item: ('paper towels', 'eggs', 'cereals', 'milk') , 0.040
# item: ('yogurt', 'toilet paper', 'eggs', 'milk') , 0.040
# item: ('shampoo', 'yogurt', 'eggs', 'juice') , 0.040
# item: ('shampoo', 'sandwich loaves', 'individual meals', 'poultry') , 0.040
# item: ('mixes', 'dinner rolls', 'poultry', 'cheeses') , 0.040
# item: ('soap', 'toilet paper', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('lunch meat', 'waffles', 'spaghetti sauce', 'dinner rolls') , 0.040
# item: ('ice cream', 'soda', 'spaghetti sauce', 'poultry') , 0.040
# item: ('pasta', 'waffles', 'soda', 'cereals') , 0.040
# item: ('individual meals', 'soda', 'spaghetti sauce', 'bagels') , 0.040
# item: ('soap', 'juice', 'poultry', 'laundry detergent') , 0.040
# item: ('aluminum foil', 'mixes', 'juice', 'cheeses') , 0.040
# item: ('toilet paper', 'bagels', 'ketchup', 'cereals') , 0.040
# item: ('yogurt', 'juice', 'poultry', 'all- purpose') , 0.040
# item: ('toilet paper', 'eggs', 'dinner rolls', 'poultry') , 0.040
# item: ('toilet paper', 'cereals', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('ice cream', 'paper towels', 'pasta', 'bagels') , 0.040
# item: ('lunch meat', 'yogurt', 'tortillas', 'dinner rolls') , 0.040
# item: ('fruits', 'mixes', 'dishwashing liquid/detergent', 'milk') , 0.040
# item: ('yogurt', 'mixes', 'cereals', 'milk') , 0.040
# item: ('waffles', 'mixes', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('aluminum foil', 'pasta', 'soda', 'hand soap') , 0.040
# item: ('yogurt', 'spaghetti sauce', 'milk', 'juice') , 0.040
# item: ('yogurt', 'bagels', 'dishwashing liquid/detergent', 'dinner rolls') , 0.040
# item: ('yogurt', 'soap', 'waffles', 'pasta') , 0.040
# item: ('lunch meat', 'ice cream', 'paper towels', 'soda') , 0.040
# item: ('butter', 'soda', 'eggs', 'individual meals') , 0.040
# item: ('butter', 'paper towels', 'cereals', 'poultry') , 0.040
# item: ('yogurt', 'ice cream', 'waffles', 'cheeses') , 0.040
# item: ('lunch meat', 'soap', 'waffles', 'sandwich bags') , 0.040
# item: ('vegetables', 'butter', 'flour', 'beef') , 0.040
# item: ('ice cream', 'waffles', 'spaghetti sauce', 'cheeses') , 0.040
# item: ('ice cream', 'spaghetti sauce', 'dinner rolls', 'cereals') , 0.040
# item: ('mixes', 'ketchup', 'spaghetti sauce', 'flour') , 0.040
# item: ('soap', 'dishwashing liquid/detergent', 'milk', 'poultry') , 0.040
# item: ('yogurt', 'spaghetti sauce', 'milk', 'cheeses') , 0.040
# item: ('butter', 'soda', 'eggs', 'cereals') , 0.040
# item: ('aluminum foil', 'bagels', 'individual meals', 'juice') , 0.040
# item: ('lunch meat', 'sandwich bags', 'poultry', 'laundry detergent') , 0.040
# item: ('coffee/tea', 'shampoo', 'yogurt', 'cereals') , 0.040
# item: ('toilet paper', 'sugar', 'soda', 'milk') , 0.040
# item: ('coffee/tea', 'ice cream', 'milk', 'poultry') , 0.040
# item: ('eggs', 'dishwashing liquid/detergent', 'poultry', 'laundry detergent') , 0.040
# item: ('lunch meat', 'toilet paper', 'bagels', 'dishwashing liquid/detergent') , 0.040
# item: ('all- purpose', 'soap', 'cheeses', 'laundry detergent') , 0.040
# item: ('soap', 'cereals', 'milk', 'laundry detergent') , 0.040
# item: ('pasta', 'cereals', 'bagels', 'cheeses') , 0.040
# item: ('lunch meat', 'fruits', 'butter', 'waffles') , 0.040
# item: ('lunch meat', 'toilet paper', 'poultry', 'beef') , 0.040
# item: ('ice cream', 'ketchup', 'juice', 'cheeses') , 0.040
# item: ('pork', 'mixes', 'ketchup', 'juice') , 0.040
# item: ('yogurt', 'soda', 'spaghetti sauce', 'cheeses') , 0.040
# item: ('ice cream', 'paper towels', 'sugar', 'beef') , 0.040
# item: ('yogurt', 'all- purpose', 'waffles', 'laundry detergent') , 0.040
# item: ('spaghetti sauce', 'dishwashing liquid/detergent', 'milk', 'cereals') , 0.040
# item: ('butter', 'dinner rolls', 'poultry', 'cheeses') , 0.040
# item: ('ice cream', 'eggs', 'cereals', 'dishwashing liquid/detergent') , 0.040
# item: ('yogurt', 'fruits', 'aluminum foil', 'juice') , 0.040
# item: ('coffee/tea', 'paper towels', 'pasta', 'eggs') , 0.040
# item: ('paper towels', 'sandwich bags', 'ketchup', 'spaghetti sauce') , 0.040
# item: ('shampoo', 'cereals', 'poultry', 'beef') , 0.040
# item: ('soap', 'ice cream', 'soda', 'individual meals') , 0.040
# item: ('aluminum foil', 'paper towels', 'soda', 'eggs') , 0.040
# item: ('coffee/tea', 'waffles', 'toilet paper', 'juice') , 0.040
# item: ('eggs', 'cereals', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('lunch meat', 'fruits', 'individual meals', 'spaghetti sauce') , 0.040
# item: ('yogurt', 'toilet paper', 'soda', 'spaghetti sauce') , 0.040
# item: ('shampoo', 'cereals', 'juice', 'laundry detergent') , 0.040
# item: ('fruits', 'eggs', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('shampoo', 'yogurt', 'flour', 'dinner rolls') , 0.040
# item: ('pasta', 'hand soap', 'dinner rolls', 'soda') , 0.040
# item: ('tortillas', 'pasta', 'eggs', 'soda') , 0.040
# item: ('soap', 'ice cream', 'paper towels', 'juice') , 0.040
# item: ('aluminum foil', 'pasta', 'spaghetti sauce', 'juice') , 0.040
# item: ('aluminum foil', 'fruits', 'cereals', 'beef') , 0.040
# item: ('coffee/tea', 'yogurt', 'eggs', 'cheeses') , 0.040
# item: ('lunch meat', 'individual meals', 'poultry', 'laundry detergent') , 0.040
# item: ('yogurt', 'waffles', 'soda', 'eggs') , 0.040
# item: ('aluminum foil', 'ice cream', 'dishwashing liquid/detergent', 'beef') , 0.040
# item: ('soap', 'ice cream', 'sandwich bags', 'beef') , 0.040
# item: ('yogurt', 'mixes', 'spaghetti sauce', 'juice') , 0.040
# item: ('pork', 'mixes', 'sandwich bags', 'ketchup') , 0.040
# item: ('coffee/tea', 'lunch meat', 'toilet paper', 'individual meals') , 0.040
# item: ('eggs', 'cereals', 'dinner rolls', 'poultry') , 0.040
# item: ('soap', 'sandwich bags', 'poultry', 'beef') , 0.040
# item: ('tortillas', 'sugar', 'mixes', 'poultry') , 0.040
# item: ('yogurt', 'waffles', 'pasta', 'dinner rolls') , 0.040
# item: ('lunch meat', 'waffles', 'cereals', 'juice') , 0.040
# item: ('fruits', 'soda', 'dishwashing liquid/detergent', 'milk') , 0.040
# item: ('lunch meat', 'paper towels', 'cereals', 'dishwashing liquid/detergent') , 0.040
# item: ('coffee/tea', 'lunch meat', 'aluminum foil', 'ice cream') , 0.040
# item: ('aluminum foil', 'ice cream', 'bagels', 'dishwashing liquid/detergent') , 0.040
# item: ('waffles', 'bagels', 'individual meals', 'juice') , 0.040
# item: ('mixes', 'cereals', 'flour', 'laundry detergent') , 0.040
# item: ('paper towels', 'bagels', 'cereals', 'beef') , 0.040
# item: ('lunch meat', 'fruits', 'ice cream', 'cheeses') , 0.040
# item: ('aluminum foil', 'milk', 'poultry', 'all- purpose') , 0.040
# item: ('aluminum foil', 'cereals', 'poultry', 'cheeses') , 0.040
# item: ('sandwich bags', 'waffles', 'bagels', 'cheeses') , 0.040
# item: ('pasta', 'soda', 'dishwashing liquid/detergent', 'cheeses') , 0.040
# item: ('waffles', 'soda', 'dishwashing liquid/detergent', 'dinner rolls') , 0.040
# item: ('soap', 'eggs', 'ketchup', 'all- purpose') , 0.040
# item: ('ice cream', 'sandwich bags', 'cereals', 'cheeses') , 0.040
# item: ('fruits', 'soap', 'sugar', 'poultry') , 0.040
# item: ('paper towels', 'eggs', 'cereals', 'poultry') , 0.040
# item: ('ice cream', 'dishwashing liquid/detergent', 'dinner rolls', 'poultry') , 0.040
# item: ('coffee/tea', 'yogurt', 'aluminum foil', 'mixes') , 0.040
# item: ('tortillas', 'bagels', 'dishwashing liquid/detergent', 'dinner rolls') , 0.040
# item: ('butter', 'sandwich bags', 'cereals', 'laundry detergent') , 0.040
# item: ('vegetables', 'pork', 'sandwich bags', 'hand soap') , 0.040
# item: ('all- purpose', 'soap', 'sandwich bags', 'laundry detergent') , 0.040
# item: ('lunch meat', 'dinner rolls', 'poultry', 'cheeses') , 0.040
# item: ('lunch meat', 'soap', 'eggs', 'dishwashing liquid/detergent') , 0.040
# item: ('lunch meat', 'fruits', 'waffles', 'individual meals') , 0.040
# item: ('aluminum foil', 'toilet paper', 'juice', 'beef') , 0.040
# item: ('yogurt', 'aluminum foil', 'waffles', 'soda') , 0.040
# item: ('soda', 'eggs', 'juice', 'ketchup') , 0.040
# item: ('yogurt', 'bagels', 'milk', 'juice') , 0.040
# item: ('yogurt', 'cereals', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('coffee/tea', 'pork', 'dishwashing liquid/detergent', 'poultry') , 0.040
# item: ('lunch meat', 'hand soap', 'juice', 'poultry') , 0.040
# item: ('sugar', 'eggs', 'beef', 'vegetables', 'soda') , 0.040
# item: ('waffles', 'eggs', 'dishwashing liquid/detergent', 'soap', 'vegetables') , 0.040
# item: ('waffles', 'vegetables', 'soda', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('pasta', 'spaghetti sauce', 'poultry', 'vegetables', 'cereals') , 0.040
# item: ('eggs', 'spaghetti sauce', 'juice', 'vegetables', 'soda') , 0.040
# item: ('lunch meat', 'dishwashing liquid/detergent', 'poultry', 'vegetables', 'cereals') , 0.040
# item: ('sugar', 'eggs', 'dishwashing liquid/detergent', 'vegetables', 'soda') , 0.040
# item: ('spaghetti sauce', 'hand soap', 'poultry', 'vegetables', 'dinner rolls') , 0.040
# item: ('waffles', 'spaghetti sauce', 'vegetables', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('poultry', 'aluminum foil', 'ice cream', 'vegetables', 'cheeses') , 0.040
# item: ('eggs', 'dishwashing liquid/detergent', 'vegetables', 'paper towels', 'dinner rolls') , 0.040
# item: ('eggs', 'milk', 'vegetables', 'soap', 'soda') , 0.040
# item: ('yogurt', 'juice', 'aluminum foil', 'vegetables', 'bagels') , 0.040
# item: ('sugar', 'juice', 'poultry', 'vegetables', 'dinner rolls') , 0.040
# item: ('sandwich loaves', 'poultry', 'vegetables', 'individual meals', 'cheeses') , 0.040
# item: ('coffee/tea', 'pasta', 'poultry', 'vegetables', 'cereals') , 0.040
# item: ('poultry', 'shampoo', 'laundry detergent', 'vegetables', 'cheeses') , 0.040
# item: ('yogurt', 'sandwich loaves', 'poultry', 'vegetables', 'individual meals') , 0.040
# item: ('spaghetti sauce', 'poultry', 'vegetables', 'bagels', 'dinner rolls') , 0.040
# item: ('sugar', 'poultry', 'shampoo', 'vegetables', 'dinner rolls') , 0.040
# item: ('coffee/tea', 'yogurt', 'poultry', 'vegetables', 'flour') , 0.040
# item: ('lunch meat', 'waffles', 'poultry', 'fruits', 'vegetables') , 0.040
# item: ('eggs', 'vegetables', 'butter', 'soda', 'dinner rolls') , 0.040
# item: ('mixes', 'poultry', 'vegetables', 'cereals', 'dinner rolls') , 0.040
# item: ('spaghetti sauce', 'milk', 'poultry', 'vegetables', 'dinner rolls') , 0.040
# item: ('mixes', 'dishwashing liquid/detergent', 'poultry', 'vegetables', 'bagels') , 0.040
# item: ('lunch meat', 'eggs', 'dishwashing liquid/detergent', 'vegetables', 'soda') , 0.040
# item: ('eggs', 'vegetables', 'soda', 'bagels', 'dinner rolls') , 0.040
# item: ('yogurt', 'mixes', 'milk', 'poultry', 'vegetables') , 0.040
# item: ('eggs', 'dishwashing liquid/detergent', 'vegetables', 'ice cream', 'paper towels') , 0.040
# item: ('waffles', 'vegetables', 'ice cream', 'soap', 'soda') , 0.040
# item: ('lunch meat', 'dishwashing liquid/detergent', 'poultry', 'vegetables', 'soda') , 0.040
# item: ('eggs', 'beef', 'vegetables', 'soda', 'cheeses') , 0.040
# item: ('pasta', 'vegetables', 'paper towels', 'ice cream', 'dinner rolls') , 0.040
# item: ('eggs', 'vegetables', 'ice cream', 'soda', 'dinner rolls') , 0.040
# item: ('eggs', 'dishwashing liquid/detergent', 'vegetables', 'bagels', 'dinner rolls') , 0.040
# item: ('toilet paper', 'eggs', 'dishwashing liquid/detergent', 'vegetables', 'bagels') , 0.040
# item: ('eggs', 'vegetables', 'ice cream', 'soap', 'soda') , 0.040
# item: ('aluminum foil', 'ice cream', 'vegetables', 'sandwich bags', 'cheeses') , 0.040
# item: ('eggs', 'vegetables', 'soda', 'cereals', 'dinner rolls') , 0.040
# item: ('coffee/tea', 'eggs', 'poultry', 'vegetables', 'dinner rolls') , 0.040
# item: ('lunch meat', 'eggs', 'poultry', 'vegetables', 'dinner rolls') , 0.040
# item: ('spaghetti sauce', 'poultry', 'vegetables', 'soda', 'laundry detergent') , 0.040
# item: ('sandwich loaves', 'poultry', 'vegetables', 'ice cream', 'soap') , 0.040
# item: ('lunch meat', 'aluminum foil', 'paper towels', 'ice cream', 'vegetables') , 0.040
# item: ('spaghetti sauce', 'juice', 'vegetables', 'soda', 'laundry detergent') , 0.040
# item: ('eggs', 'vegetables', 'paper towels', 'cereals', 'dinner rolls') , 0.040
# item: ('yogurt', 'poultry', 'vegetables', 'cereals', 'dinner rolls') , 0.040
# item: ('yogurt', 'eggs', 'dishwashing liquid/detergent', 'vegetables', 'paper towels') , 0.040
# item: ('toilet paper', 'juice', 'shampoo', 'vegetables', 'aluminum foil') , 0.040
# item: ('pasta', 'eggs', 'vegetables', 'ice cream', 'soda') , 0.040
# item: ('spaghetti sauce', 'juice', 'vegetables', 'soda', 'dinner rolls') , 0.040
# item: ('waffles', 'eggs', 'dishwashing liquid/detergent', 'poultry', 'vegetables') , 0.040
# item: ('spaghetti sauce', 'poultry', 'aluminum foil', 'ice cream', 'vegetables') , 0.040
# item: ('pasta', 'vegetables', 'aluminum foil', 'soda', 'dinner rolls') , 0.040
# item: ('yogurt', 'aluminum foil', 'vegetables', 'sandwich bags', 'cheeses') , 0.040
# item: ('pasta', 'poultry', 'vegetables', 'paper towels', 'dinner rolls') , 0.040
# item: ('mixes', 'spaghetti sauce', 'poultry', 'vegetables', 'dinner rolls') , 0.040
# item: ('eggs', 'poultry', 'vegetables', 'dinner rolls', 'cheeses') , 0.040
# item: ('milk', 'poultry', 'vegetables', 'cereals', 'dinner rolls') , 0.040
# item: ('lunch meat', 'sandwich loaves', 'poultry', 'vegetables', 'dinner rolls') , 0.040
# item: ('mixes', 'eggs', 'dishwashing liquid/detergent', 'vegetables', 'aluminum foil') , 0.040
# item: ('lunch meat', 'juice', 'poultry', 'shampoo', 'vegetables') , 0.040
# item: ('poultry', 'vegetables', 'soda', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('lunch meat', 'mixes', 'dishwashing liquid/detergent', 'poultry', 'vegetables') , 0.040
# item: ('yogurt', 'dishwashing liquid/detergent', 'poultry', 'vegetables', 'cereals') , 0.040
# item: ('lunch meat', 'waffles', 'vegetables', 'soda', 'laundry detergent') , 0.040
# item: ('lunch meat', 'spaghetti sauce', 'juice', 'shampoo', 'vegetables') , 0.040
# item: ('pasta', 'eggs', 'dishwashing liquid/detergent', 'vegetables', 'soda') , 0.040
# item: ('eggs', 'dishwashing liquid/detergent', 'fruits', 'vegetables', 'bagels') , 0.040
# item: ('yogurt', 'eggs', 'juice', 'vegetables', 'soda') , 0.040
# item: ('sandwich bags', 'vegetables', 'bagels', 'cereals', 'cheeses') , 0.040
# item: ('spaghetti sauce', 'juice', 'vegetables', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('sugar', 'eggs', 'poultry', 'vegetables', 'soda') , 0.040
# item: ('eggs', 'dishwashing liquid/detergent', 'poultry', 'vegetables', 'bagels') , 0.040
# item: ('sugar', 'juice', 'poultry', 'vegetables', 'aluminum foil') , 0.040
# item: ('mixes', 'dishwashing liquid/detergent', 'poultry', 'vegetables', 'dinner rolls') , 0.040
# item: ('spaghetti sauce', 'poultry', 'vegetables', 'dinner rolls', 'cheeses') , 0.040
# item: ('toilet paper', 'juice', 'poultry', 'vegetables', 'laundry detergent') , 0.040
# item: ('lunch meat', 'vegetables', 'soap', 'soda', 'individual meals') , 0.040
# item: ('pasta', 'vegetables', 'ice cream', 'paper towels', 'cereals') , 0.040
# item: ('eggs', 'milk', 'poultry', 'vegetables', 'cereals') , 0.040
# item: ('poultry', 'vegetables', 'ice cream', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('spaghetti sauce', 'poultry', 'vegetables', 'soda', 'dinner rolls') , 0.040
# item: ('eggs', 'poultry', 'vegetables', 'soap', 'soda') , 0.040
# item: ('dishwashing liquid/detergent', 'poultry', 'vegetables', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('lunch meat', 'sugar', 'poultry', 'vegetables', 'cereals') , 0.040
# item: ('coffee/tea', 'dishwashing liquid/detergent', 'poultry', 'vegetables', 'dinner rolls') , 0.040
# item: ('mixes', 'eggs', 'dishwashing liquid/detergent', 'poultry', 'vegetables') , 0.040
# item: ('sugar', 'waffles', 'dishwashing liquid/detergent', 'vegetables', 'soda') , 0.040
# item: ('toilet paper', 'ketchup', 'vegetables', 'paper towels', 'all- purpose') , 0.040
# item: ('eggs', 'dishwashing liquid/detergent', 'poultry', 'vegetables', 'cereals') , 0.040
# item: ('eggs', 'dishwashing liquid/detergent', 'poultry', 'vegetables', 'dinner rolls') , 0.040
# item: ('lunch meat', 'dishwashing liquid/detergent', 'vegetables', 'ice cream', 'soda') , 0.040
# item: ('pasta', 'poultry', 'vegetables', 'soda', 'dinner rolls') , 0.040
# item: ('eggs', 'vegetables', 'soda', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('yogurt', 'mixes', 'juice', 'vegetables', 'aluminum foil') , 0.040
# item: ('eggs', 'dishwashing liquid/detergent', 'poultry', 'vegetables', 'ice cream') , 0.040
# item: ('milk', 'vegetables', 'cereals', 'dinner rolls', 'laundry detergent') , 0.040
# item: ('yogurt', 'eggs', 'juice', 'vegetables', 'all- purpose') , 0.040
# item: ('lunch meat', 'eggs', 'soap', 'vegetables', 'soda') , 0.040
# item: ('eggs', 'dishwashing liquid/detergent', 'milk', 'vegetables', 'bagels') , 0.040
# item: ('yogurt', 'juice', 'poultry', 'vegetables', 'dinner rolls') , 0.040
# item: ('mixes', 'poultry', 'shampoo', 'vegetables', 'aluminum foil') , 0.040
# item: ('cheeses', 'vegetables', 'sandwich bags', 'cereals', 'laundry detergent') , 0.040
# item: ('yogurt', 'eggs', 'cereals', 'laundry detergent') , 0.041
# item: ('lunch meat', 'individual meals', 'dinner rolls', 'laundry detergent') , 0.041
# item: ('yogurt', 'mixes', 'cereals', 'poultry') , 0.041
# item: ('paper towels', 'spaghetti sauce', 'dinner rolls', 'poultry') , 0.041
# item: ('soap', 'ice cream', 'aluminum foil', 'soda') , 0.041
# item: ('ice cream', 'soda', 'dinner rolls', 'poultry') , 0.041
# item: ('yogurt', 'sugar', 'flour', 'dinner rolls') , 0.041
# item: ('aluminum foil', 'cereals', 'dishwashing liquid/detergent', 'poultry') , 0.041
# item: ('soap', 'paper towels', 'toilet paper', 'all- purpose') , 0.041
# item: ('dinner rolls', 'hand soap', 'juice', 'poultry') , 0.041
# item: ('aluminum foil', 'soda', 'spaghetti sauce', 'juice') , 0.041
# item: ('tortillas', 'yogurt', 'sandwich bags', 'dinner rolls') , 0.041
# item: ('yogurt', 'sandwich bags', 'milk', 'cheeses') , 0.041
# item: ('lunch meat', 'fruits', 'dishwashing liquid/detergent', 'all- purpose') , 0.041
# item: ('yogurt', 'aluminum foil', 'milk', 'cheeses') , 0.041
# item: ('tortillas', 'bagels', 'spaghetti sauce', 'milk') , 0.041
# item: ('soap', 'toilet paper', 'spaghetti sauce', 'all- purpose') , 0.041
# item: ('ice cream', 'paper towels', 'sandwich bags', 'pasta') , 0.041
# item: ('shampoo', 'paper towels', 'soda', 'eggs') , 0.041
# item: ('fruits', 'ice cream', 'poultry', 'cheeses') , 0.041
# item: ('lunch meat', 'aluminum foil', 'ice cream', 'waffles') , 0.041
# item: ('yogurt', 'sandwich bags', 'milk', 'beef') , 0.041
# item: ('ice cream', 'sugar', 'soda', 'poultry') , 0.041
# item: ('yogurt', 'bagels', 'cereals', 'milk') , 0.041
# item: ('lunch meat', 'soap', 'individual meals', 'cheeses') , 0.041
# item: ('vegetables', 'butter', 'toilet paper', 'pasta') , 0.041
# item: ('shampoo', 'juice', 'hand soap', 'poultry') , 0.041
# item: ('ice cream', 'waffles', 'soda', 'beef') , 0.041
# item: ('lunch meat', 'soap', 'individual meals', 'flour') , 0.041
# item: ('soap', 'ketchup', 'spaghetti sauce', 'all- purpose') , 0.041
# item: ('waffles', 'spaghetti sauce', 'dinner rolls', 'laundry detergent') , 0.041
# item: ('aluminum foil', 'mixes', 'bagels', 'dishwashing liquid/detergent') , 0.041
# item: ('yogurt', 'dishwashing liquid/detergent', 'milk', 'poultry') , 0.041
# item: ('lunch meat', 'soap', 'poultry', 'all- purpose') , 0.041
# item: ('fruits', 'soap', 'dishwashing liquid/detergent', 'beef') , 0.041
# item: ('fruits', 'aluminum foil', 'ice cream', 'spaghetti sauce') , 0.041
# item: ('coffee/tea', 'vegetables', 'dishwashing liquid/detergent', 'hand soap') , 0.041
# item: ('lunch meat', 'waffles', 'spaghetti sauce', 'poultry') , 0.041
# item: ('ice cream', 'pasta', 'eggs', 'bagels') , 0.041
# item: ('soap', 'toilet paper', 'ketchup', 'cheeses') , 0.041
# item: ('paper towels', 'eggs', 'dinner rolls', 'laundry detergent') , 0.041
# item: ('paper towels', 'waffles', 'sugar', 'soda') , 0.041
# item: ('soap', 'soda', 'eggs', 'flour') , 0.041
# item: ('soap', 'ice cream', 'soda', 'beef') , 0.041
# item: ('lunch meat', 'yogurt', 'eggs', 'dishwashing liquid/detergent') , 0.041
# item: ('bagels', 'soda', 'dinner rolls', 'poultry') , 0.041
# item: ('sandwich bags', 'bagels', 'individual meals', 'cereals') , 0.041
# item: ('ice cream', 'paper towels', 'pasta', 'milk') , 0.041
# item: ('sandwich loaves', 'individual meals', 'spaghetti sauce', 'poultry') , 0.041
# item: ('aluminum foil', 'ice cream', 'paper towels', 'cereals') , 0.041
# item: ('toilet paper', 'pasta', 'dishwashing liquid/detergent', 'dinner rolls') , 0.041
# item: ('waffles', 'pasta', 'spaghetti sauce', 'dinner rolls') , 0.041
# item: ('sugar', 'toilet paper', 'soda', 'poultry') , 0.041
# item: ('yogurt', 'ice cream', 'poultry', 'cheeses') , 0.041
# item: ('ice cream', 'soda', 'eggs', 'ketchup') , 0.041
# item: ('juice', 'dinner rolls', 'poultry', 'all- purpose') , 0.041
# item: ('soap', 'sandwich loaves', 'soda', 'ketchup') , 0.041
# item: ('mixes', 'ketchup', 'poultry', 'laundry detergent') , 0.041
# item: ('shampoo', 'yogurt', 'toilet paper', 'flour') , 0.041
# item: ('yogurt', 'pasta', 'waffles', 'soda') , 0.041
# item: ('vegetables', 'butter', 'sandwich bags', 'beef') , 0.041
# item: ('soap', 'waffles', 'ketchup', 'beef') , 0.041
# item: ('waffles', 'soda', 'individual meals', 'dishwashing liquid/detergent') , 0.041
# item: ('lunch meat', 'fruits', 'soap', 'waffles') , 0.041
# item: ('vegetables', 'butter', 'individual meals', 'all- purpose') , 0.041
# item: ('lunch meat', 'sugar', 'bagels', 'poultry') , 0.041
# item: ('soap', 'waffles', 'spaghetti sauce', 'laundry detergent') , 0.041
# item: ('yogurt', 'ketchup', 'milk', 'juice') , 0.041
# item: ('mixes', 'dishwashing liquid/detergent', 'poultry', 'beef') , 0.041
# item: ('lunch meat', 'coffee/tea', 'ice cream', 'cheeses') , 0.041
# item: ('ice cream', 'sugar', 'dinner rolls', 'cheeses') , 0.041
# item: ('soda', 'eggs', 'individual meals', 'dinner rolls') , 0.041
# item: ('soap', 'sandwich bags', 'cereals', 'cheeses') , 0.041
# item: ('ice cream', 'cereals', 'poultry', 'beef') , 0.041
# item: ('pasta', 'dinner rolls', 'poultry', 'cheeses') , 0.041
# item: ('coffee/tea', 'paper towels', 'eggs', 'milk') , 0.041
# item: ('soda', 'eggs', 'spaghetti sauce', 'poultry') , 0.041
# item: ('shampoo', 'cereals', 'milk', 'beef') , 0.041
# item: ('yogurt', 'milk', 'dinner rolls', 'poultry') , 0.041
# item: ('vegetables', 'butter', 'pasta', 'flour') , 0.041
# item: ('shampoo', 'toilet paper', 'soda', 'dinner rolls') , 0.041
# item: ('juice', 'waffles', 'soda', 'dinner rolls') , 0.041
# item: ('aluminum foil', 'mixes', 'ketchup', 'flour') , 0.041
# item: ('toilet paper', 'waffles', 'juice', 'poultry') , 0.041
# item: ('yogurt', 'individual meals', 'bagels', 'cereals') , 0.041
# item: ('mixes', 'cereals', 'poultry', 'cheeses') , 0.041
# item: ('yogurt', 'sandwich loaves', 'pasta', 'poultry') , 0.041
# item: ('soap', 'ice cream', 'soda', 'spaghetti sauce') , 0.041
# item: ('soda', 'spaghetti sauce', 'juice', 'poultry') , 0.041
# item: ('pasta', 'eggs', 'cereals', 'soda') , 0.041
# item: ('yogurt', 'aluminum foil', 'ketchup', 'juice') , 0.041
# item: ('lunch meat', 'paper towels', 'bagels', 'cereals') , 0.041
# item: ('fruits', 'sugar', 'cereals', 'beef') , 0.041
# item: ('yogurt', 'aluminum foil', 'cereals', 'cheeses') , 0.041
# item: ('lunch meat', 'coffee/tea', 'ice cream', 'soda') , 0.041
# item: ('paper towels', 'ice cream', 'milk', 'beef') , 0.041
# item: ('shampoo', 'spaghetti sauce', 'juice', 'laundry detergent') , 0.041
# item: ('soap', 'sugar', 'poultry', 'laundry detergent') , 0.041
# item: ('toilet paper', 'soda', 'spaghetti sauce', 'dinner rolls') , 0.041
# item: ('soap', 'paper towels', 'mixes', 'ketchup') , 0.041
# item: ('lunch meat', 'soap', 'soda', 'dishwashing liquid/detergent') , 0.041
# item: ('aluminum foil', 'soap', 'sandwich loaves', 'ketchup') , 0.041
# item: ('shampoo', 'toilet paper', 'juice', 'beef') , 0.041
# item: ('all- purpose', 'soda', 'dinner rolls', 'laundry detergent') , 0.041
# item: ('yogurt', 'aluminum foil', 'soda', 'spaghetti sauce') , 0.041
# item: ('tortillas', 'sugar', 'soda', 'poultry') , 0.041
# item: ('coffee/tea', 'milk', 'poultry', 'cheeses') , 0.041
# item: ('soap', 'waffles', 'pasta', 'dishwashing liquid/detergent') , 0.041
# item: ('pork', 'soap', 'soda', 'ketchup') , 0.041
# item: ('waffles', 'dishwashing liquid/detergent', 'pasta', 'bagels') , 0.041
# item: ('shampoo', 'yogurt', 'aluminum foil', 'poultry') , 0.041
# item: ('soap', 'pasta', 'ketchup', 'all- purpose') , 0.041
# item: ('shampoo', 'yogurt', 'coffee/tea', 'aluminum foil') , 0.041
# item: ('pork', 'mixes', 'ketchup', 'dishwashing liquid/detergent') , 0.041
# item: ('yogurt', 'pasta', 'dishwashing liquid/detergent', 'dinner rolls') , 0.041
# item: ('waffles', 'soda', 'dishwashing liquid/detergent', 'milk') , 0.041
# item: ('aluminum foil', 'ice cream', 'sugar', 'beef') , 0.041
# item: ('shampoo', 'lunch meat', 'cereals', 'beef') , 0.041
# item: ('tortillas', 'pork', 'vegetables', 'cereals') , 0.041
# item: ('shampoo', 'waffles', 'cereals', 'juice') , 0.041
# item: ('shampoo', 'juice', 'spaghetti sauce', 'dinner rolls') , 0.041
# item: ('dinner rolls', 'aluminum foil', 'eggs', 'juice') , 0.041
# item: ('ice cream', 'soda', 'eggs', 'cheeses') , 0.041
# item: ('soap', 'bagels', 'eggs', 'milk') , 0.041
# item: ('eggs', 'toilet paper', 'ketchup', 'all- purpose') , 0.041
# item: ('lunch meat', 'waffles', 'dishwashing liquid/detergent', 'flour') , 0.041
# item: ('spaghetti sauce', 'dishwashing liquid/detergent', 'dinner rolls', 'poultry') , 0.041
# item: ('coffee/tea', 'cereals', 'milk', 'laundry detergent') , 0.041
# item: ('fruits', 'vegetables', 'toilet paper', 'sandwich loaves') , 0.041
# item: ('coffee/tea', 'yogurt', 'dinner rolls', 'cheeses') , 0.041
# item: ('shampoo', 'fruits', 'sandwich bags', 'cheeses') , 0.041
# item: ('aluminum foil', 'toilet paper', 'soda', 'juice') , 0.041
# item: ('soap', 'toilet paper', 'soda', 'poultry') , 0.041
# item: ('lunch meat', 'ice cream', 'waffles', 'dishwashing liquid/detergent') , 0.041
# item: ('aluminum foil', 'ice cream', 'waffles', 'pasta') , 0.041
# item: ('pork', 'soap', 'sandwich bags', 'ketchup') , 0.041
# item: ('coffee/tea', 'shampoo', 'mixes', 'poultry') , 0.041
# item: ('paper towels', 'eggs', 'cereals', 'beef') , 0.041
# item: ('mixes', 'cereals', 'dishwashing liquid/detergent', 'milk') , 0.041
# item: ('soap', 'waffles', 'soda', 'flour') , 0.041
# item: ('yogurt', 'mixes', 'poultry', 'laundry detergent') , 0.041
# item: ('coffee/tea', 'yogurt', 'eggs', 'milk') , 0.041
# item: ('soap', 'spaghetti sauce', 'poultry', 'all- purpose') , 0.041
# item: ('aluminum foil', 'ice cream', 'paper towels', 'pasta') , 0.041
# item: ('lunch meat', 'paper towels', 'bagels', 'dishwashing liquid/detergent') , 0.041
# item: ('shampoo', 'yogurt', 'aluminum foil', 'soda') , 0.041
# item: ('aluminum foil', 'ice cream', 'sugar', 'cheeses') , 0.041
# item: ('soap', 'waffles', 'ketchup', 'juice') , 0.041
# item: ('paper towels', 'cereals', 'dinner rolls', 'poultry') , 0.041
# item: ('vegetables', 'pork', 'butter', 'hand soap') , 0.041
# item: ('coffee/tea', 'shampoo', 'dinner rolls', 'poultry') , 0.041
# item: ('fruits', 'vegetables', 'butter', 'hand soap') , 0.041
# item: ('yogurt', 'cereals', 'milk', 'cheeses') , 0.041
# item: ('ice cream', 'pasta', 'cereals', 'dinner rolls') , 0.041
# item: ('lunch meat', 'dishwashing liquid/detergent', 'juice', 'poultry') , 0.041
# item: ('coffee/tea', 'cereals', 'milk', 'poultry') , 0.041
# item: ('pasta', 'eggs', 'cereals', 'beef') , 0.041
# item: ('waffles', 'toilet paper', 'poultry', 'beef') , 0.041
# item: ('butter', 'toilet paper', 'bagels', 'dinner rolls') , 0.041
# item: ('waffles', 'pasta', 'spaghetti sauce', 'cheeses') , 0.041
# item: ('pasta', 'waffles', 'soda', 'laundry detergent') , 0.041
# item: ('ice cream', 'cereals', 'poultry', 'laundry detergent') , 0.041
# item: ('shampoo', 'vegetables', 'sandwich bags', 'hand soap') , 0.041
# item: ('soap', 'ice cream', 'cereals', 'milk') , 0.041
# item: ('yogurt', 'soda', 'eggs', 'dishwashing liquid/detergent') , 0.041
# item: ('yogurt', 'aluminum foil', 'cereals', 'beef') , 0.041
# item: ('soap', 'soda', 'spaghetti sauce', 'poultry') , 0.041
# item: ('aluminum foil', 'pasta', 'eggs', 'soda') , 0.041
# item: ('ice cream', 'cereals', 'dishwashing liquid/detergent', 'milk') , 0.041
# item: ('tortillas', 'sandwich bags', 'milk', 'poultry') , 0.041
# item: ('bagels', 'eggs', 'milk', 'beef') , 0.041
# item: ('tortillas', 'sugar', 'toilet paper', 'poultry') , 0.041
# item: ('lunch meat', 'soap', 'waffles', 'poultry') , 0.041
# item: ('coffee/tea', 'bagels', 'ketchup', 'juice') , 0.041
# item: ('coffee/tea', 'shampoo', 'lunch meat', 'cereals') , 0.041
# item: ('dishwashing liquid/detergent', 'pasta', 'soda', 'milk') , 0.041
# item: ('soap', 'toilet paper', 'soda', 'eggs') , 0.041
# item: ('lunch meat', 'sugar', 'dinner rolls', 'laundry detergent') , 0.041
# item: ('coffee/tea', 'waffles', 'soda', 'cheeses') , 0.041
# item: ('paper towels', 'toilet paper', 'ketchup', 'all- purpose') , 0.041
# item: ('tortillas', 'shampoo', 'vegetables', 'hand soap') , 0.041
# item: ('lunch meat', 'fruits', 'aluminum foil', 'spaghetti sauce') , 0.041
# item: ('shampoo', 'paper towels', 'dinner rolls', 'poultry') , 0.041
# item: ('all- purpose', 'soap', 'dinner rolls', 'laundry detergent') , 0.041
# item: ('yogurt', 'sandwich loaves', 'eggs', 'poultry') , 0.041
# item: ('coffee/tea', 'cereals', 'milk', 'cheeses') , 0.041
# item: ('sandwich loaves', 'soda', 'ketchup', 'cheeses') , 0.041
# item: ('pasta', 'bagels', 'individual meals', 'soda') , 0.041
# item: ('aluminum foil', 'mixes', 'spaghetti sauce', 'juice') , 0.041
# item: ('yogurt', 'paper towels', 'toilet paper', 'juice') , 0.041
# item: ('yogurt', 'mixes', 'dishwashing liquid/detergent', 'all- purpose') , 0.041
# item: ('paper towels', 'sandwich bags', 'cereals', 'poultry') , 0.041
# item: ('tortillas', 'sugar', 'eggs', 'poultry') , 0.041
# item: ('lunch meat', 'fruits', 'aluminum foil', 'ice cream') , 0.041
# item: ('mixes', 'bagels', 'eggs', 'dishwashing liquid/detergent') , 0.041
# item: ('coffee/tea', 'lunch meat', 'soap', 'ice cream') , 0.041
# item: ('butter', 'sandwich loaves', 'poultry', 'cheeses') , 0.041
# item: ('yogurt', 'fruits', 'dishwashing liquid/detergent', 'milk') , 0.041
# item: ('tortillas', 'soda', 'eggs', 'dinner rolls') , 0.041
# item: ('tortillas', 'yogurt', 'sandwich bags', 'milk') , 0.041
# item: ('ice cream', 'sugar', 'pasta', 'cheeses') , 0.041
# item: ('pasta', 'spaghetti sauce', 'poultry', 'cheeses') , 0.041
# item: ('coffee/tea', 'pork', 'soap', 'ketchup') , 0.041
# item: ('pork', 'dinner rolls', 'poultry', 'all- purpose') , 0.041
# item: ('yogurt', 'ice cream', 'pasta', 'cereals') , 0.041
# item: ('shampoo', 'lunch meat', 'waffles', 'cereals') , 0.041
# item: ('shampoo', 'laundry detergent', 'dinner rolls', 'cheeses') , 0.041
# item: ('soap', 'eggs', 'milk', 'poultry') , 0.041
# item: ('pasta', 'dishwashing liquid/detergent', 'poultry', 'all- purpose') , 0.041
# item: ('coffee/tea', 'dishwashing liquid/detergent', 'poultry', 'cheeses') , 0.041
# item: ('waffles', 'bagels', 'dishwashing liquid/detergent', 'dinner rolls') , 0.041
# item: ('shampoo', 'lunch meat', 'cereals', 'juice') , 0.041
# item: ('lunch meat', 'fruits', 'waffles', 'sandwich loaves') , 0.041
# item: ('coffee/tea', 'ketchup', 'cereals', 'juice') , 0.041
# item: ('sandwich bags', 'cereals', 'milk', 'laundry detergent') , 0.041
# item: ('aluminum foil', 'pasta', 'dinner rolls', 'poultry') , 0.041
# item: ('lunch meat', 'ice cream', 'pasta', 'dishwashing liquid/detergent') , 0.041
# item: ('pasta', 'soda', 'spaghetti sauce', 'hand soap') , 0.041
# item: ('sugar', 'dishwashing liquid/detergent', 'poultry', 'beef') , 0.041
# item: ('butter', 'sandwich bags', 'poultry', 'cheeses') , 0.041
# item: ('fruits', 'ice cream', 'paper towels', 'dishwashing liquid/detergent') , 0.041
# item: ('beef', 'ice cream', 'sandwich bags', 'cheeses') , 0.041
# item: ('lunch meat', 'ice cream', 'sandwich loaves', 'individual meals') , 0.041
# item: ('tortillas', 'butter', 'toilet paper', 'bagels') , 0.041
# item: ('ice cream', 'eggs', 'individual meals', 'dishwashing liquid/detergent') , 0.041
# item: ('ice cream', 'paper towels', 'sandwich bags', 'dishwashing liquid/detergent') , 0.041
# item: ('mixes', 'ketchup', 'juice', 'poultry') , 0.041
# item: ('lunch meat', 'toilet paper', 'eggs', 'poultry') , 0.041
# item: ('soap', 'waffles', 'spaghetti sauce', 'poultry') , 0.041
# item: ('pork', 'paper towels', 'vegetables', 'dinner rolls') , 0.041
# item: ('yogurt', 'aluminum foil', 'soda', 'dinner rolls') , 0.041
# item: ('shampoo', 'individual meals', 'juice', 'poultry') , 0.041
# item: ('coffee/tea', 'aluminum foil', 'soap', 'waffles') , 0.041
# item: ('soap', 'waffles', 'individual meals', 'juice') , 0.041
# item: ('sandwich bags', 'soda', 'milk', 'poultry') , 0.041
# item: ('fruits', 'eggs', 'dishwashing liquid/detergent', 'cheeses') , 0.041
# item: ('yogurt', 'mixes', 'spaghetti sauce', 'cheeses') , 0.041
# item: ('aluminum foil', 'sandwich bags', 'dinner rolls', 'cheeses') , 0.041
# item: ('paper towels', 'soda', 'eggs', 'beef') , 0.041
# item: ('lunch meat', 'ice cream', 'eggs', 'cereals') , 0.041
# item: ('yogurt', 'aluminum foil', 'cereals', 'poultry') , 0.041
# item: ('lunch meat', 'spaghetti sauce', 'juice', 'poultry') , 0.041
# item: ('aluminum foil', 'paper towels', 'pasta', 'eggs') , 0.041
# item: ('lunch meat', 'flour', 'juice', 'poultry') , 0.041
# item: ('sandwich loaves', 'individual meals', 'dinner rolls', 'poultry') , 0.041
# item: ('ice cream', 'spaghetti sauce', 'poultry', 'laundry detergent') , 0.041
# item: ('sandwich bags', 'cereals', 'dishwashing liquid/detergent', 'poultry') , 0.041
# item: ('coffee/tea', 'toilet paper', 'ketchup', 'juice') , 0.041
# item: ('ice cream', 'sandwich loaves', 'bagels', 'individual meals') , 0.041
# item: ('soap', 'milk', 'poultry', 'laundry detergent') , 0.041
# item: ('fruits', 'aluminum foil', 'milk', 'beef') , 0.041
# item: ('yogurt', 'pasta', 'poultry', 'cheeses') , 0.041
# item: ('coffee/tea', 'lunch meat', 'juice', 'poultry') , 0.041
# item: ('coffee/tea', 'yogurt', 'pasta', 'cheeses') , 0.041
# item: ('yogurt', 'pasta', 'eggs', 'poultry') , 0.041
# item: ('juice', 'eggs', 'dinner rolls', 'ketchup') , 0.041
# item: ('yogurt', 'aluminum foil', 'soda', 'cheeses') , 0.041
# item: ('yogurt', 'toilet paper', 'waffles', 'soda') , 0.041
# item: ('lunch meat', 'ice cream', 'waffles', 'sandwich loaves') , 0.041
# item: ('lunch meat', 'sandwich loaves', 'individual meals', 'dishwashing liquid/detergent') , 0.041
# item: ('yogurt', 'mixes', 'poultry', 'cheeses') , 0.041
# item: ('shampoo', 'dishwashing liquid/detergent', 'dinner rolls', 'poultry') , 0.041
# item: ('yogurt', 'pasta', 'cereals', 'cheeses') , 0.041
# item: ('toilet paper', 'soda', 'flour', 'cheeses') , 0.041
# item: ('juice', 'eggs', 'dishwashing liquid/detergent', 'dinner rolls') , 0.041
# item: ('shampoo', 'lunch meat', 'coffee/tea', 'ice cream') , 0.041
# item: ('aluminum foil', 'waffles', 'pasta', 'dinner rolls') , 0.041
# item: ('lunch meat', 'coffee/tea', 'soap', 'cheeses') , 0.041
# item: ('beef', 'fruits', 'spaghetti sauce', 'cheeses') , 0.041
# item: ('yogurt', 'aluminum foil', 'eggs', 'dishwashing liquid/detergent') , 0.041
# item: ('spaghetti sauce', 'milk', 'cereals', 'laundry detergent') , 0.041
# item: ('cereals', 'dinner rolls', 'poultry', 'beef') , 0.041
# item: ('beef', 'fruits', 'cereals', 'all- purpose') , 0.041
# item: ('aluminum foil', 'cereals', 'juice', 'spaghetti sauce') , 0.041
# item: ('fruits', 'soap', 'eggs', 'dishwashing liquid/detergent') , 0.041
# item: ('paper towels', 'sandwich bags', 'cereals', 'beef') , 0.041
# item: ('shampoo', 'yogurt', 'aluminum foil', 'toilet paper') , 0.041
# item: ('lunch meat', 'yogurt', 'waffles', 'cereals') , 0.041
# item: ('paper towels', 'bagels', 'eggs', 'milk') , 0.041
# item: ('coffee/tea', 'vegetables', 'hand soap', 'all- purpose') , 0.041
# item: ('sandwich loaves', 'toilet paper', 'poultry', 'cheeses') , 0.041
# item: ('coffee/tea', 'yogurt', 'cereals', 'juice') , 0.041
# item: ('tortillas', 'cereals', 'milk', 'laundry detergent') , 0.041
# item: ('lunch meat', 'ice cream', 'dishwashing liquid/detergent', 'juice') , 0.041
# item: ('fruits', 'paper towels', 'eggs', 'dishwashing liquid/detergent') , 0.041
# item: ('toilet paper', 'soda', 'eggs', 'poultry') , 0.041
# item: ('ice cream', 'soda', 'eggs', 'spaghetti sauce') , 0.041
# item: ('toilet paper', 'waffles', 'eggs', 'cheeses') , 0.041
# item: ('lunch meat', 'eggs', 'individual meals', 'beef') , 0.041
# item: ('lunch meat', 'paper towels', 'milk', 'poultry') , 0.041
# item: ('soap', 'pork', 'ketchup', 'all- purpose') , 0.041
# item: ('yogurt', 'ice cream', 'pasta', 'cheeses') , 0.041
# item: ('mixes', 'pasta', 'dishwashing liquid/detergent', 'flour') , 0.041
# item: ('coffee/tea', 'pork', 'cereals', 'cheeses') , 0.041
# item: ('yogurt', 'dishwashing liquid/detergent', 'poultry', 'laundry detergent') , 0.041
# item: ('sugar', 'eggs', 'poultry', 'cheeses') , 0.041
# item: ('waffles', 'pasta', 'bagels', 'juice') , 0.041
# item: ('soda', 'eggs', 'individual meals', 'bagels') , 0.041
# item: ('fruits', 'ice cream', 'soap', 'poultry') , 0.041
# item: ('soap', 'butter', 'poultry', 'all- purpose') , 0.041
# item: ('coffee/tea', 'yogurt', 'waffles', 'cereals') , 0.041
# item: ('yogurt', 'aluminum foil', 'eggs', 'dinner rolls') , 0.041
# item: ('aluminum foil', 'ice cream', 'cereals', 'beef') , 0.041
# item: ('lunch meat', 'fruits', 'spaghetti sauce', 'dishwashing liquid/detergent') , 0.041
# item: ('toilet paper', 'dinner rolls', 'poultry', 'laundry detergent') , 0.041
# item: ('soap', 'spaghetti sauce', 'poultry', 'laundry detergent') , 0.041
# item: ('laundry detergent', 'soda', 'spaghetti sauce', 'cheeses') , 0.041
# item: ('paper towels', 'toilet paper', 'cereals', 'all- purpose') , 0.041
# ...
# Rule: ('yogurt', 'beef', 'pasta') ==> ('vegetables',) , 0.868
# Rule: ('coffee/tea', 'milk', 'juice') ==> ('vegetables',) , 0.868
# Rule: ('coffee/tea', 'eggs', 'toilet paper') ==> ('vegetables',) , 0.868
# Rule: ('dishwashing liquid/detergent', 'soap', 'sugar') ==> ('vegetables',) , 0.868
# Rule: ('pork', 'poultry', 'bagels') ==> ('vegetables',) , 0.868
# Rule: ('ketchup', 'juice', 'flour') ==> ('vegetables',) , 0.868
# Rule: ('laundry detergent', 'pork', 'sandwich bags') ==> ('vegetables',) , 0.868
# Rule: ('individual meals', 'dishwashing liquid/detergent', 'sugar') ==> ('vegetables',) , 0.868
# Rule: ('yogurt', 'all- purpose', 'spaghetti sauce') ==> ('vegetables',) , 0.868
# Rule: ('cereals', 'sugar', 'soda') ==> ('vegetables',) , 0.868
# Rule: ('shampoo', 'hand soap', 'sandwich loaves') ==> ('vegetables',) , 0.868
# Rule: ('eggs', 'spaghetti sauce', 'ketchup') ==> ('vegetables',) , 0.868
# Rule: ('ketchup', 'sugar', 'soda') ==> ('vegetables',) , 0.868
# Rule: ('eggs', 'fruits', 'flour') ==> ('vegetables',) , 0.868
# Rule: ('poultry', 'sugar', 'sandwich bags') ==> ('vegetables',) , 0.868
# Rule: ('cereals', 'waffles', 'mixes') ==> ('vegetables',) , 0.868
# Rule: ('dishwashing liquid/detergent', 'flour', 'laundry detergent') ==> ('vegetables',) , 0.868
# Rule: ('paper towels', 'sandwich loaves', 'cheeses') ==> ('vegetables',) , 0.868
# Rule: ('dinner rolls', 'ice cream', 'toilet paper') ==> ('vegetables',) , 0.868
# Rule: ('spaghetti sauce', 'ice cream', 'all- purpose') ==> ('vegetables',) , 0.868
# Rule: ('flour', 'sugar', 'beef') ==> ('vegetables',) , 0.868
# Rule: ('shampoo', 'milk', 'dinner rolls') ==> ('vegetables',) , 0.868
# Rule: ('eggs', 'pork', 'mixes') ==> ('vegetables',) , 0.868
# Rule: ('dinner rolls', 'juice', 'butter') ==> ('vegetables',) , 0.868
# Rule: ('soap', 'paper towels', 'beef') ==> ('vegetables',) , 0.868
# Rule: ('shampoo', 'laundry detergent') ==> ('vegetables',) , 0.869
# Rule: ('cereals', 'milk', 'laundry detergent') ==> ('vegetables',) , 0.869
# Rule: ('eggs', 'dishwashing liquid/detergent', 'soda') ==> ('vegetables',) , 0.869
# Rule: ('yogurt', 'aluminum foil', 'mixes') ==> ('vegetables',) , 0.869
# Rule: ('milk', 'sugar') ==> ('vegetables',) , 0.869
# Rule: ('shampoo', 'fruits', 'eggs') ==> ('vegetables',) , 0.869
# Rule: ('individual meals', 'sugar', 'sandwich bags') ==> ('vegetables',) , 0.869
# Rule: ('laundry detergent', 'sandwich loaves', 'all- purpose') ==> ('vegetables',) , 0.869
# Rule: ('ketchup', 'milk', 'sugar') ==> ('vegetables',) , 0.869
# Rule: ('yogurt', 'fruits', 'butter') ==> ('vegetables',) , 0.869
# Rule: ('waffles', 'milk', 'sandwich loaves') ==> ('vegetables',) , 0.869
# Rule: ('sandwich loaves', 'fruits', 'sugar') ==> ('vegetables',) , 0.869
# Rule: ('pork', 'hand soap', 'soap') ==> ('vegetables',) , 0.869
# Rule: ('butter', 'sugar', 'flour') ==> ('vegetables',) , 0.869
# Rule: ('coffee/tea', 'pork', 'sugar') ==> ('vegetables',) , 0.869
# Rule: ('ketchup', 'laundry detergent', 'sandwich bags') ==> ('vegetables',) , 0.869
# Rule: ('poultry', 'mixes', 'soda') ==> ('vegetables',) , 0.869
# Rule: ('lunch meat', 'sugar', 'beef') ==> ('vegetables',) , 0.869
# Rule: ('soap', 'sandwich loaves', 'all- purpose') ==> ('vegetables',) , 0.869
# Rule: ('ketchup', 'aluminum foil', 'juice') ==> ('vegetables',) , 0.869
# Rule: ('flour', 'cheeses', 'sandwich bags') ==> ('vegetables',) , 0.869
# Rule: ('waffles', 'ice cream', 'sugar') ==> ('vegetables',) , 0.869
# Rule: ('lunch meat', 'fruits', 'ice cream') ==> ('vegetables',) , 0.869
# Rule: ('lunch meat', 'soap', 'sugar') ==> ('vegetables',) , 0.869
# Rule: ('lunch meat', 'waffles', 'bagels') ==> ('vegetables',) , 0.869
# Rule: ('spaghetti sauce', 'juice', 'all- purpose') ==> ('vegetables',) , 0.869
# Rule: ('individual meals', 'cereals', 'sandwich bags') ==> ('vegetables',) , 0.869
# Rule: ('ketchup', 'aluminum foil', 'waffles') ==> ('vegetables',) , 0.869
# Rule: ('poultry', 'sandwich loaves', 'sandwich bags') ==> ('vegetables',) , 0.869
# Rule: ('lunch meat', 'ice cream', 'bagels') ==> ('vegetables',) , 0.869
# Rule: ('coffee/tea', 'cereals', 'juice') ==> ('vegetables',) , 0.869
# Rule: ('eggs', 'soap', 'mixes') ==> ('vegetables',) , 0.869
# Rule: ('ketchup', 'poultry', 'laundry detergent') ==> ('vegetables',) , 0.869
# Rule: ('lunch meat', 'soap', 'paper towels') ==> ('vegetables',) , 0.869
# Rule: ('individual meals', 'waffles', 'bagels') ==> ('vegetables',) , 0.869
# Rule: ('shampoo', 'juice', 'cheeses') ==> ('vegetables',) , 0.869
# Rule: ('aluminum foil', 'paper towels', 'soda') ==> ('vegetables',) , 0.869
# Rule: ('yogurt', 'poultry', 'soda') ==> ('vegetables',) , 0.869
# Rule: ('yogurt', 'fruits', 'paper towels') ==> ('vegetables',) , 0.869
# Rule: ('dishwashing liquid/detergent', 'paper towels', 'poultry') ==> ('vegetables',) , 0.869
# Rule: ('coffee/tea', 'pork', 'lunch meat') ==> ('vegetables',) , 0.869
# Rule: ('individual meals', 'waffles', 'cheeses') ==> ('vegetables',) , 0.869
# Rule: ('dinner rolls', 'sugar', 'bagels') ==> ('vegetables',) , 0.869
# Rule: ('lunch meat', 'sugar', 'toilet paper') ==> ('vegetables',) , 0.869
# Rule: ('lunch meat', 'laundry detergent', 'sandwich bags') ==> ('vegetables',) , 0.869
# Rule: ('ketchup', 'dinner rolls', 'juice') ==> ('vegetables',) , 0.869
# Rule: ('ketchup', 'pork', 'laundry detergent') ==> ('vegetables',) , 0.870
# Rule: ('lunch meat', 'hand soap', 'shampoo') ==> ('vegetables',) , 0.870
# Rule: ('aluminum foil', 'ice cream', 'soda') ==> ('vegetables',) , 0.870
# Rule: ('lunch meat', 'soap', 'ice cream') ==> ('vegetables',) , 0.870
# Rule: ('yogurt', 'hand soap', 'sugar') ==> ('vegetables',) , 0.870
# Rule: ('tortillas', 'paper towels', 'all- purpose') ==> ('vegetables',) , 0.870
# Rule: ('eggs', 'cereals', 'beef') ==> ('vegetables',) , 0.870
# Rule: ('dinner rolls', 'sugar', 'sandwich bags') ==> ('vegetables',) , 0.870
# Rule: ('paper towels', 'sandwich loaves', 'pasta') ==> ('vegetables',) , 0.870
# Rule: ('sandwich loaves', 'mixes', 'all- purpose') ==> ('vegetables',) , 0.870
# Rule: ('shampoo', 'pork', 'laundry detergent') ==> ('vegetables',) , 0.870
# Rule: ('coffee/tea', 'all- purpose', 'soda') ==> ('vegetables',) , 0.870
# Rule: ('coffee/tea', 'butter', 'pasta') ==> ('vegetables',) , 0.870
# Rule: ('yogurt', 'cheeses', 'beef') ==> ('vegetables',) , 0.870
# Rule: ('dinner rolls', 'sugar', 'soda') ==> ('vegetables',) , 0.870
# Rule: ('shampoo', 'laundry detergent', 'cheeses') ==> ('vegetables',) , 0.870
# Rule: ('soap', 'mixes', 'pasta') ==> ('vegetables',) , 0.870
# Rule: ('milk', 'dinner rolls', 'waffles') ==> ('vegetables',) , 0.870
# Rule: ('soap', 'hand soap', 'beef') ==> ('vegetables',) , 0.870
# Rule: ('spaghetti sauce', 'aluminum foil', 'sandwich bags') ==> ('vegetables',) , 0.870
# Rule: ('yogurt', 'aluminum foil', 'beef') ==> ('vegetables',) , 0.870
# Rule: ('dinner rolls', 'sandwich loaves', 'beef') ==> ('vegetables',) , 0.870
# Rule: ('individual meals', 'hand soap', 'juice') ==> ('vegetables',) , 0.870
# Rule: ('tortillas', 'aluminum foil', 'butter') ==> ('vegetables',) , 0.870
# Rule: ('shampoo', 'ice cream', 'all- purpose') ==> ('vegetables',) , 0.870
# Rule: ('shampoo', 'juice', 'lunch meat') ==> ('vegetables',) , 0.870
# Rule: ('lunch meat', 'dinner rolls', 'ketchup') ==> ('vegetables',) , 0.870
# Rule: ('waffles', 'sugar', 'sandwich bags') ==> ('vegetables',) , 0.870
# Rule: ('lunch meat', 'aluminum foil', 'poultry') ==> ('vegetables',) , 0.870
# Rule: ('dishwashing liquid/detergent', 'juice', 'sugar') ==> ('vegetables',) , 0.870
# Rule: ('waffles', 'paper towels', 'sandwich loaves') ==> ('vegetables',) , 0.870
# Rule: ('spaghetti sauce', 'ice cream', 'poultry') ==> ('vegetables',) , 0.870
# Rule: ('aluminum foil', 'bagels') ==> ('vegetables',) , 0.870
# Rule: ('yogurt', 'sandwich bags') ==> ('vegetables',) , 0.870
# Rule: ('ketchup', 'juice', 'pasta') ==> ('vegetables',) , 0.870
# Rule: ('coffee/tea', 'pork', 'eggs') ==> ('vegetables',) , 0.870
# Rule: ('paper towels', 'waffles', 'sandwich bags') ==> ('vegetables',) , 0.870
# Rule: ('sandwich loaves', 'mixes', 'bagels') ==> ('vegetables',) , 0.870
# Rule: ('spaghetti sauce', 'soap', 'sugar') ==> ('vegetables',) , 0.870
# Rule: ('dishwashing liquid/detergent', 'juice', 'toilet paper') ==> ('vegetables',) , 0.870
# Rule: ('poultry', 'mixes', 'pasta') ==> ('vegetables',) , 0.870
# Rule: ('lunch meat', 'pork', 'paper towels') ==> ('vegetables',) , 0.870
# Rule: ('soap', 'aluminum foil', 'bagels') ==> ('vegetables',) , 0.870
# Rule: ('lunch meat', 'laundry detergent', 'bagels') ==> ('vegetables',) , 0.870
# Rule: ('soap', 'butter', 'laundry detergent') ==> ('vegetables',) , 0.870
# Rule: ('hand soap', 'ice cream', 'pasta') ==> ('vegetables',) , 0.870
# Rule: ('laundry detergent', 'waffles', 'pasta') ==> ('vegetables',) , 0.870
# Rule: ('bagels', 'aluminum foil', 'pork') ==> ('vegetables',) , 0.870
# Rule: ('lunch meat', 'dishwashing liquid/detergent', 'cheeses') ==> ('vegetables',) , 0.870
# Rule: ('shampoo', 'sugar', 'lunch meat') ==> ('vegetables',) , 0.870
# Rule: ('ketchup', 'yogurt', 'waffles') ==> ('vegetables',) , 0.870
# Rule: ('eggs', 'mixes', 'bagels') ==> ('vegetables',) , 0.870
# Rule: ('paper towels', 'sandwich loaves', 'mixes') ==> ('vegetables',) , 0.870
# Rule: ('yogurt', 'fruits', 'mixes') ==> ('vegetables',) , 0.870
# Rule: ('coffee/tea', 'cereals', 'sandwich loaves') ==> ('vegetables',) , 0.870
# Rule: ('ice cream', 'mixes', 'laundry detergent') ==> ('vegetables',) , 0.870
# Rule: ('ketchup', 'fruits', 'cheeses') ==> ('vegetables',) , 0.870
# Rule: ('shampoo', 'juice', 'sandwich loaves') ==> ('vegetables',) , 0.870
# Rule: ('juice', 'aluminum foil', 'flour') ==> ('vegetables',) , 0.870
# Rule: ('juice', 'dinner rolls', 'toilet paper') ==> ('vegetables',) , 0.870
# Rule: ('lunch meat', 'milk', 'ice cream') ==> ('vegetables',) , 0.870
# Rule: ('lunch meat', 'dinner rolls', 'sandwich bags') ==> ('vegetables',) , 0.870
# Rule: ('lunch meat', 'dishwashing liquid/detergent', 'shampoo') ==> ('vegetables',) , 0.870
# Rule: ('aluminum foil', 'paper towels', 'laundry detergent') ==> ('vegetables',) , 0.870
# Rule: ('shampoo', 'cereals', 'spaghetti sauce') ==> ('vegetables',) , 0.870
# Rule: ('ketchup', 'fruits', 'butter') ==> ('vegetables',) , 0.870
# Rule: ('fruits', 'pork', 'sandwich loaves') ==> ('vegetables',) , 0.870
# Rule: ('eggs', 'paper towels', 'dinner rolls', 'ice cream') ==> ('vegetables',) , 0.870
# Rule: ('yogurt', 'dinner rolls', 'poultry', 'all- purpose') ==> ('vegetables',) , 0.870
# Rule: ('spaghetti sauce', 'dinner rolls', 'poultry', 'individual meals') ==> ('vegetables',) , 0.870
# Rule: ('dinner rolls', 'aluminum foil', 'juice', 'poultry') ==> ('vegetables',) , 0.870
# Rule: ('lunch meat', 'dishwashing liquid/detergent', 'fruits', 'poultry') ==> ('vegetables',) , 0.870
# Rule: ('coffee/tea', 'yogurt', 'aluminum foil', 'juice') ==> ('vegetables',) , 0.870
# Rule: ('eggs', 'dishwashing liquid/detergent', 'ice cream', 'soda') ==> ('vegetables',) , 0.870
# Rule: ('dinner rolls', 'waffles') ==> ('vegetables',) , 0.870
# Rule: ('eggs', 'all- purpose', 'pasta') ==> ('vegetables',) , 0.871
# Rule: ('cereals', 'aluminum foil', 'toilet paper') ==> ('vegetables',) , 0.871
# Rule: ('spaghetti sauce', 'poultry', 'bagels') ==> ('vegetables',) , 0.871
# Rule: ('yogurt', 'juice', 'sandwich bags') ==> ('vegetables',) , 0.871
# Rule: ('aluminum foil', 'paper towels', 'mixes') ==> ('vegetables',) , 0.871
# Rule: ('aluminum foil', 'ice cream', 'sandwich bags') ==> ('vegetables',) , 0.871
# Rule: ('ketchup', 'paper towels', 'soda') ==> ('vegetables',) , 0.871
# Rule: ('dishwashing liquid/detergent', 'paper towels', 'laundry detergent') ==> ('vegetables',) , 0.871
# Rule: ('juice', 'sandwich loaves', 'poultry') ==> ('vegetables',) , 0.871
# Rule: ('spaghetti sauce', 'bagels', 'pasta') ==> ('vegetables',) , 0.871
# Rule: ('ketchup', 'paper towels', 'sandwich bags') ==> ('vegetables',) , 0.871
# Rule: ('ketchup', 'yogurt', 'aluminum foil') ==> ('vegetables',) , 0.871
# Rule: ('lunch meat', 'yogurt', 'juice') ==> ('vegetables',) , 0.871
# Rule: ('waffles', 'sugar', 'beef') ==> ('vegetables',) , 0.871
# Rule: ('shampoo', 'soap', 'poultry') ==> ('vegetables',) , 0.871
# Rule: ('shampoo', 'individual meals', 'cheeses') ==> ('vegetables',) , 0.871
# Rule: ('aluminum foil', 'flour', 'mixes') ==> ('vegetables',) , 0.871
# Rule: ('eggs', 'toilet paper', 'ketchup') ==> ('vegetables',) , 0.871
# Rule: ('yogurt', 'milk', 'pasta') ==> ('vegetables',) , 0.871
# Rule: ('lunch meat', 'eggs', 'beef') ==> ('vegetables',) , 0.871
# Rule: ('eggs', 'spaghetti sauce', 'soap') ==> ('vegetables',) , 0.871
# Rule: ('aluminum foil', 'poultry', 'pasta') ==> ('vegetables',) , 0.871
# Rule: ('laundry detergent', 'soap', 'sandwich bags') ==> ('vegetables',) , 0.871
# Rule: ('dishwashing liquid/detergent', 'cheeses', 'laundry detergent') ==> ('vegetables',) , 0.871
# Rule: ('ice cream', 'sugar', 'pasta') ==> ('vegetables',) , 0.871
# Rule: ('spaghetti sauce', 'dinner rolls', 'sugar') ==> ('vegetables',) , 0.871
# Rule: ('spaghetti sauce', 'dinner rolls', 'laundry detergent') ==> ('vegetables',) , 0.871
# Rule: ('lunch meat', 'cereals', 'poultry') ==> ('vegetables',) , 0.871
# Rule: ('lunch meat', 'poultry', 'laundry detergent') ==> ('vegetables',) , 0.871
# Rule: ('cereals', 'dinner rolls', 'pasta') ==> ('vegetables',) , 0.871
# Rule: ('eggs', 'dishwashing liquid/detergent', 'ice cream') ==> ('vegetables',) , 0.871
# Rule: ('yogurt', 'butter', 'spaghetti sauce') ==> ('vegetables',) , 0.871
# Rule: ('sugar', 'mixes', 'sandwich bags') ==> ('vegetables',) , 0.871
# Rule: ('soap', 'butter', 'flour') ==> ('vegetables',) , 0.871
# Rule: ('yogurt', 'butter', 'beef') ==> ('vegetables',) , 0.871
# Rule: ('aluminum foil', 'butter', 'sugar') ==> ('vegetables',) , 0.871
# Rule: ('cereals', 'all- purpose', 'soda') ==> ('vegetables',) , 0.871
# Rule: ('spaghetti sauce', 'sugar', 'sandwich bags') ==> ('vegetables',) , 0.871
# Rule: ('bagels', 'hand soap', 'sandwich bags') ==> ('vegetables',) , 0.871
# Rule: ('butter', 'flour', 'bagels') ==> ('vegetables',) , 0.871
# Rule: ('sandwich loaves', 'paper towels', 'butter') ==> ('vegetables',) , 0.871
# Rule: ('individual meals', 'milk', 'sugar') ==> ('vegetables',) , 0.871
# Rule: ('coffee/tea', 'dishwashing liquid/detergent', 'sandwich loaves') ==> ('vegetables',) , 0.871
# Rule: ('dishwashing liquid/detergent', 'hand soap', 'toilet paper') ==> ('vegetables',) , 0.871
# Rule: ('pork', 'dinner rolls', 'soap') ==> ('vegetables',) , 0.871
# Rule: ('yogurt', 'juice', 'poultry') ==> ('vegetables',) , 0.871
# Rule: ('lunch meat', 'toilet paper', 'ketchup') ==> ('vegetables',) , 0.871
# Rule: ('pork', 'sandwich loaves', 'poultry') ==> ('vegetables',) , 0.871
# Rule: ('eggs', 'aluminum foil', 'pork') ==> ('vegetables',) , 0.871
# Rule: ('laundry detergent', 'waffles', 'beef') ==> ('vegetables',) , 0.871
# Rule: ('pork', 'butter', 'laundry detergent') ==> ('vegetables',) , 0.871
# Rule: ('hand soap', 'juice', 'butter') ==> ('vegetables',) , 0.871
# Rule: ('pork', 'toilet paper', 'sugar') ==> ('vegetables',) , 0.871
# Rule: ('eggs', 'hand soap', 'bagels') ==> ('vegetables',) , 0.871
# Rule: ('shampoo', 'spaghetti sauce', 'eggs') ==> ('vegetables',) , 0.871
# Rule: ('yogurt', 'hand soap', 'laundry detergent') ==> ('vegetables',) , 0.871
# Rule: ('eggs', 'individual meals', 'laundry detergent') ==> ('vegetables',) , 0.871
# Rule: ('eggs', 'flour', 'laundry detergent') ==> ('vegetables',) , 0.871
# Rule: ('eggs', 'flour', 'sugar') ==> ('vegetables',) , 0.871
# Rule: ('dinner rolls', 'sandwich loaves', 'all- purpose') ==> ('vegetables',) , 0.871
# Rule: ('individual meals', 'hand soap', 'laundry detergent') ==> ('vegetables',) , 0.871
# Rule: ('coffee/tea', 'yogurt', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.871
# Rule: ('yogurt', 'sugar', 'sandwich bags') ==> ('vegetables',) , 0.871
# Rule: ('milk', 'sandwich loaves', 'cheeses') ==> ('vegetables',) , 0.871
# Rule: ('shampoo', 'yogurt', 'soap') ==> ('vegetables',) , 0.871
# Rule: ('coffee/tea', 'fruits', 'eggs') ==> ('vegetables',) , 0.871
# Rule: ('lunch meat', 'juice', 'soda') ==> ('vegetables',) , 0.871
# Rule: ('eggs', 'pork', 'sandwich bags') ==> ('vegetables',) , 0.871
# Rule: ('individual meals', 'dishwashing liquid/detergent', 'hand soap') ==> ('vegetables',) , 0.871

# %%
print ('# # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #') 
print ('Case 3 (minimum support=0.33 and minimum confidence=0.4)')
print ('Case 3 Reasoning: Confidence value further decreases when we increase the support, also decreasing the confidence will reduce the total number of rules generated. Thus, if people purchase vegetable then there is 44.9% chance that they will also going to purchase poultry. But if we purchase poultry there is higher percentage of 78.7% we will buy vegetables.In comparision to previous support values, there is approx increase of 30% in final values.')
print ('Case 3 Output:')
# !python apriori.py -f dataset.csv -s 0.33 -c 0.4
# Out:
# # # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #
# Case 3 (minimum support=0.33 and minimum confidence=0.4)
# Case 3 Reasoning: Confidence value further decreases when we increase the support, also decreasing the confidence will reduce the total number of rules generated. Thus, if people purchase vegetable then there is 44.9% chance that they will also going to purchase poultry. But if we purchase poultry there is higher percentage of 78.7% we will buy vegetables.In comparision to previous support values, there is approx increase of 30% in final values.
# Case 3 Output:
#
# ------------ITEMS-----------------
# item: ('poultry', 'vegetables') , 0.332
# item: ('hand soap',) , 0.346
# item: ('sandwich loaves',) , 0.349
# item: ('flour',) , 0.353
# item: ('pork',) , 0.356
# item: ('sugar',) , 0.361
# item: ('paper towels',) , 0.363
# item: ('butter',) , 0.368
# item: ('sandwich bags',) , 0.368
# item: ('shampoo',) , 0.369
# item: ('tortillas',) , 0.370
# item: ('fruits',) , 0.371
# item: ('ketchup',) , 0.371
# item: ('pasta',) , 0.371
# item: ('spaghetti sauce',) , 0.373
# item: ('all- purpose',) , 0.375
# item: ('beef',) , 0.375
# item: ('individual meals',) , 0.376
# item: ('mixes',) , 0.376
# item: ('juice',) , 0.377
# item: ('laundry detergent',) , 0.378
# item: ('toilet paper',) , 0.378
# item: ('soap',) , 0.379
# item: ('coffee/tea',) , 0.379
# item: ('milk',) , 0.380
# item: ('yogurt',) , 0.385
# item: ('aluminum foil',) , 0.385
# item: ('bagels',) , 0.385
# item: ('dishwashing liquid/detergent',) , 0.388
# item: ('dinner rolls',) , 0.389
# item: ('eggs',) , 0.390
# item: ('soda',) , 0.391
# item: ('cheeses',) , 0.391
# item: ('waffles',) , 0.394
# item: ('lunch meat',) , 0.395
# item: ('cereals',) , 0.396
# item: ('ice cream',) , 0.399
# item: ('poultry',) , 0.421
# item: ('vegetables',) , 0.739
#
# ------------RULES-----------------
# Rule: ('vegetables',) ==> ('poultry',) , 0.449
# Rule: ('poultry',) ==> ('vegetables',) , 0.787

# %% [markdown]
# ## Report
# (separately in pdf)

# %% [markdown]
# Take a small dataset (it can be any dataset). Show 3 support and confidence for the small dataset. Show the rules for all the 3 cases using the formula.
# Provide references where ever necessary.

# %% [markdown]
# # References
#
# [01] https://www.kaggle.com/acostasg/random-shopping-cart
#
# [02] https://github.com/asaini/Apriori

# %% [markdown]
# # Rubric
# * [02 points] - Student Details
# * [08 points] - Comply with submission instructions
# * [30 points] - DataSet Preprocess
# * [30 points] - Run apriory.py
# * [5 points] - Evaluate Results
# * [25 points] - Report
